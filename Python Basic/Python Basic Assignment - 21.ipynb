# %% [markdown]
# # Assignment 21

# %% [markdown]
# SUBMITTED BY: DIVESH ANKOLEKAR

# %% [markdown]
# **1. Add the current date to the text file today.txt as a string.**

# %%
import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 22-02-2023

# %% [markdown]
# **2. Read the text file today.txt into the string today_string**

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 22-02-2023

# %% [markdown]
# **3. Parse the date from today_string.**

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2023-02-22 00:00:00

# %% [markdown]
# **4. List the files in your current directory**

# %%
import os
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# -1.14-windows.xml
# .condarc
# .gitconfig
# application_log.txt
# books.csv
# books.db
# Class-10 _4th JUNE.ipynb
# Class-11 _ (5th JUNE).ipynb
# Class-13 _(12th JUNE).ipynb
# Class-14 _(18th JUNE).ipynb
# Class-17 30th JUNE.ipynb
# Class-6__(21st  MAY).ipynb
# CLASS-7 NOTES _(22nd May).ipynb
# CLASS-8__(28th MAY).ipynb
# Class-9 __(29th MAY).ipynb
# class_4 (15th NOVEMBER).ipynb
# Div.txt
# Divesh
# divesh1.txt
# edyst_project-1.ipynb
# edyst_project-2.ipynb
# file.avi
# file.BCS
# file.db
# file.dbb
# file.dmp
# file.DSP
# file.err
# file.esav
# file.full
# file.log
# file.mlv
# file.mntr
# file.mode
# file.rst
# file.rsx
# file.rth
# file.stat
# FSDS-EDA.ipynb
# Linear_Regression-Model.ipynb
# list.txt
# Logistic-Regression_MODEL.ipynb
# Multilayer Perceptron_ML-MODEL.ipynb
# multilayer-perceptron_Model.ipynb
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.0.regtrans-ms
# NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.1.regtrans-ms
# NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.2.regtrans-ms
# NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.blf
# NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TM.blf
# NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000001.regtrans-ms
# NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000002.regtrans-ms
# ntuser.ini
# PRACTICE OF CLASSS_3.ipynb
# Python Basic Assignment - 1.ipynb
# Python Basic Assignment - 10.ipynb
# Python Basic Assignment - 11.ipynb
# Python Basic Assignment - 12.ipynb
# Python Basic Assignment - 13.ipynb
# Python Basic Assignment - 14.ipynb
# Python Basic Assignment - 15.ipynb
# Python Basic Assignment - 16.ipynb
# Python Basic Assignment - 17.ipynb
# Python Basic Assignment - 18.ipynb
# Python Basic Assignment - 19.ipynb
# Python Basic Assignment - 2.ipynb
# Python Basic Assignment - 20.ipynb
# Python Basic Assignment - 3.ipynb
# Python Basic Assignment - 4.ipynb
# Python Basic Assignment - 5.ipynb
# Python Basic Assignment - 6.ipynb
# Python Basic Assignment - 7.ipynb
# Python Basic Assignment - 8.ipynb
# Python Basic Assignment - 9.ipynb
# TASK-1 __(Class -- 4).ipynb
# TASK-2_CLASS-6.ipynb
# TASK-3__Class-8.ipynb
# TASK-4 _Class-9.ipynb
# TASK-5 _ Class-11.ipynb
# test.ipynb
# test.txt
# test5.txt
# test6.txt
# test7.txt
# testd.txt
# today.txt
# university_records.csv
# Untitled.ipynb
# Untitled1.ipynb
# Untitled10.ipynb
# Untitled11.ipynb
# Untitled12.ipynb
# Untitled13.ipynb
# Untitled14.ipynb
# Untitled15.ipynb
# Untitled16.ipynb
# Untitled17.ipynb
# Untitled18.ipynb
# Untitled19.ipynb
# Untitled2.ipynb
# Untitled20.ipynb
# Untitled21.ipynb
# Untitled22.ipynb
# Untitled23.ipynb
# Untitled24.ipynb
# Untitled25.ipynb
# Untitled26.ipynb
# Untitled27.ipynb
# Untitled28.ipynb
# Untitled29.ipynb
# Untitled3.ipynb
# Untitled30.ipynb
# Untitled31.ipynb
# Untitled32.ipynb
# Untitled33.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# Untitled9.ipynb
# WORK-3.ipynb
# environments.txt
# config.yaml
# breakpoints.lst
# recent-files.lst
# Class-10 _4th JUNE-checkpoint.ipynb
# Class-11 _ (5th JUNE)-checkpoint.ipynb
# Class-13 _(12th JUNE)-checkpoint.ipynb
# Class-14 _(18th JUNE)-checkpoint.ipynb
# Class-17 30th JUNE-checkpoint.ipynb
# Class-6__(21st  MAY)-checkpoint.ipynb
# CLASS-7 NOTES _(22nd May)-checkpoint.ipynb
# CLASS-8__(28th MAY)-checkpoint.ipynb
# Class-9 __(29th MAY)-checkpoint.ipynb
# class_4 (15th NOVEMBER)-checkpoint.ipynb
# edyst_project-1-checkpoint.ipynb
# edyst_project-2-checkpoint.ipynb
# FSDS-EDA-checkpoint.ipynb
# Linear_Regression-Model-checkpoint.ipynb
# Logistic-Regression_MODEL-checkpoint.ipynb
# Multilayer Perceptron_ML-MODEL-checkpoint.ipynb
# multilayer-perceptron_Model-checkpoint.ipynb
# PRACTICE OF CLASSS_3-checkpoint.ipynb
# Python Basic Assignment - 1-checkpoint.ipynb
# Python Basic Assignment - 10-checkpoint.ipynb
# Python Basic Assignment - 11-checkpoint.ipynb
# Python Basic Assignment - 12-checkpoint.ipynb
# Python Basic Assignment - 13-checkpoint.ipynb
# Python Basic Assignment - 14-checkpoint.ipynb
# Python Basic Assignment - 15-checkpoint.ipynb
# Python Basic Assignment - 16-checkpoint.ipynb
# Python Basic Assignment - 17-checkpoint.ipynb
# Python Basic Assignment - 18-checkpoint.ipynb
# Python Basic Assignment - 19-checkpoint.ipynb
# Python Basic Assignment - 2-checkpoint.ipynb
# Python Basic Assignment - 20-checkpoint.ipynb
# Python Basic Assignment - 3-checkpoint.ipynb
# Python Basic Assignment - 4-checkpoint.ipynb
# Python Basic Assignment - 5-checkpoint.ipynb
# Python Basic Assignment - 6-checkpoint.ipynb
# Python Basic Assignment - 7-checkpoint.ipynb
# Python Basic Assignment - 8-checkpoint.ipynb
# Python Basic Assignment - 9-checkpoint.ipynb
# TASK-1 __(Class -- 4)-checkpoint.ipynb
# TASK-2_CLASS-6-checkpoint.ipynb
# TASK-3__Class-8-checkpoint.ipynb
# TASK-4 _Class-9-checkpoint.ipynb
# TASK-5 _ Class-11-checkpoint.ipynb
# test-checkpoint.ipynb
# Untitled-checkpoint.ipynb
# Untitled1-checkpoint.ipynb
# Untitled10-checkpoint.ipynb
# Untitled11-checkpoint.ipynb
# Untitled12-checkpoint.ipynb
# Untitled13-checkpoint.ipynb
# Untitled14-checkpoint.ipynb
# Untitled15-checkpoint.ipynb
# Untitled16-checkpoint.ipynb
# Untitled17-checkpoint.ipynb
# Untitled18-checkpoint.ipynb
# Untitled19-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Untitled20-checkpoint.ipynb
# Untitled21-checkpoint.ipynb
# Untitled22-checkpoint.ipynb
# Untitled23-checkpoint.ipynb
# Untitled24-checkpoint.ipynb
# Untitled25-checkpoint.ipynb
# Untitled26-checkpoint.ipynb
# Untitled27-checkpoint.ipynb
# Untitled28-checkpoint.ipynb
# Untitled29-checkpoint.ipynb
# Untitled3-checkpoint.ipynb
# Untitled30-checkpoint.ipynb
# Untitled31-checkpoint.ipynb
# Untitled32-checkpoint.ipynb
# Untitled33-checkpoint.ipynb
# Untitled4-checkpoint.ipynb
# Untitled5-checkpoint.ipynb
# Untitled6-checkpoint.ipynb
# Untitled7-checkpoint.ipynb
# Untitled8-checkpoint.ipynb
# Untitled9-checkpoint.ipynb
# WORK-3-checkpoint.ipynb
# history.sqlite
# history.sqlite-journal
# README
# migrated
# fontlist-v330.json
# argv.json
# .obsolete
# extensions.json
# .vsixmanifest
# CHANGELOG.md
# browser.extension.bundle.js
# browser.server.bundle.js
# browser.server.bundle.js.LICENSE.txt
# extension.bundle.js
# folderIndex.json
# pyright.bundle.js
# pyright.bundle.js.map
# server.bundle.js
# stdlib.json
# etree.pyi
# objectify.pyi
# _multiarray_umath.pyi
# _simd.pyi
# _pocketfft_internal.pyi
# lapack_lite.pyi
# _umath_linalg.pyi
# bit_generator.pyi
# mtrand.pyi
# _bounded_integers.pyi
# _common.pyi
# _generator.pyi
# _mt19937.pyi
# _pcg64.pyi
# _philox.pyi
# _sfc64.pyi
# _sas.pyi
# algos.pyi
# groupby.pyi
# hashing.pyi
# hashtable.pyi
# index.pyi
# indexing.pyi
# internals.pyi
# interval.pyi
# join.pyi
# json.pyi
# lib.pyi
# missing.pyi
# ops.pyi
# ops_dispatch.pyi
# parsers.pyi
# properties.pyi
# reduction.pyi
# reshape.pyi
# sparse.pyi
# testing.pyi
# tslib.pyi
# writers.pyi
# base.pyi
# ccalendar.pyi
# conversion.pyi
# dtypes.pyi
# fields.pyi
# nattype.pyi
# np_datetime.pyi
# offsets.pyi
# parsing.pyi
# period.pyi
# strptime.pyi
# timedeltas.pyi
# timestamps.pyi
# timezones.pyi
# tzconversion.pyi
# vectorized.pyi
# aggregations.pyi
# indexers.pyi
# py.typed
# __init__.pyi
# commit.txt
# LICENSE.txt
# shortcuts.pyi
# __init__.pyi
# config.pyi
# registry.pyi
# __init__.pyi
# global_settings.pyi
# __init__.pyi
# __init__.pyi
# i18n.pyi
# static.pyi
# __init__.pyi
# __init__.pyi
# actions.pyi
# apps.pyi
# checks.pyi
# decorators.pyi
# exceptions.pyi
# filters.pyi
# forms.pyi
# helpers.pyi
# models.pyi
# options.pyi
# sites.pyi
# tests.pyi
# utils.pyi
# widgets.pyi
# __init__.pyi
# __init__.pyi
# admin_list.pyi
# admin_modify.pyi
# admin_urls.pyi
# base.pyi
# log.pyi
# __init__.pyi
# autocomplete.pyi
# decorators.pyi
# main.pyi
# __init__.pyi
# apps.pyi
# middleware.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# backends.pyi
# base_user.pyi
# checks.pyi
# context_processors.pyi
# decorators.pyi
# forms.pyi
# hashers.pyi
# middleware.pyi
# mixins.pyi
# models.pyi
# password_validation.pyi
# signals.pyi
# tokens.pyi
# urls.pyi
# validators.pyi
# views.pyi
# __init__.pyi
# modwsgi.pyi
# __init__.pyi
# __init__.pyi
# changepassword.pyi
# createsuperuser.pyi
# __init__.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# checks.pyi
# fields.pyi
# forms.pyi
# models.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# remove_stale_contenttypes.pyi
# __init__.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# forms.pyi
# middleware.pyi
# models.pyi
# sitemaps.pyi
# urls.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# flatpages.pyi
# __init__.pyi
# apps.pyi
# feeds.pyi
# geometry.pyi
# measure.pyi
# ptr.pyi
# shortcuts.pyi
# views.pyi
# __init__.pyi
# options.pyi
# widgets.pyi
# __init__.pyi
# __init__.pyi
# utils.pyi
# __init__.pyi
# adapter.pyi
# features.pyi
# models.pyi
# operations.pyi
# __init__.pyi
# base.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# adapter.pyi
# base.pyi
# features.pyi
# introspection.pyi
# models.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# adapter.pyi
# base.pyi
# const.pyi
# features.pyi
# introspection.pyi
# models.pyi
# operations.pyi
# pgraster.pyi
# schema.pyi
# __init__.pyi
# adapter.pyi
# base.pyi
# client.pyi
# features.pyi
# introspection.pyi
# models.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# aggregates.pyi
# fields.pyi
# functions.pyi
# lookups.pyi
# proxy.pyi
# __init__.pyi
# conversion.pyi
# __init__.pyi
# fields.pyi
# widgets.pyi
# __init__.pyi
# base.pyi
# datasource.pyi
# driver.pyi
# envelope.pyi
# error.pyi
# feature.pyi
# field.pyi
# geometries.pyi
# geomtype.pyi
# layer.pyi
# libgdal.pyi
# srs.pyi
# __init__.pyi
# ds.pyi
# errcheck.pyi
# generation.pyi
# geom.pyi
# raster.pyi
# srs.pyi
# __init__.pyi
# band.pyi
# base.pyi
# const.pyi
# source.pyi
# __init__.pyi
# base.pyi
# resources.pyi
# __init__.pyi
# base.pyi
# collections.pyi
# coordseq.pyi
# error.pyi
# factory.pyi
# geometry.pyi
# io.pyi
# libgeos.pyi
# linestring.pyi
# mutable_list.pyi
# point.pyi
# polygon.pyi
# prepared.pyi
# __init__.pyi
# coordseq.pyi
# errcheck.pyi
# geom.pyi
# io.pyi
# misc.pyi
# predicates.pyi
# prepared.pyi
# threadsafe.pyi
# topology.pyi
# __init__.pyi
# geojson.pyi
# __init__.pyi
# kml.pyi
# views.pyi
# __init__.pyi
# layermapping.pyi
# ogrinfo.pyi
# ogrinspect.pyi
# srs.pyi
# __init__.pyi
# apps.pyi
# __init__.pyi
# humanize.pyi
# __init__.pyi
# api.pyi
# apps.pyi
# constants.pyi
# context_processors.pyi
# middleware.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# base.pyi
# cookie.pyi
# fallback.pyi
# session.pyi
# __init__.pyi
# apps.pyi
# constraints.pyi
# functions.pyi
# indexes.pyi
# lookups.pyi
# operations.pyi
# search.pyi
# serializers.pyi
# signals.pyi
# utils.pyi
# validators.pyi
# __init__.pyi
# general.pyi
# mixins.pyi
# statistics.pyi
# __init__.pyi
# array.pyi
# citext.pyi
# hstore.pyi
# jsonb.pyi
# ranges.pyi
# utils.pyi
# __init__.pyi
# array.pyi
# hstore.pyi
# jsonb.py
# ranges.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# middleware.pyi
# models.pyi
# __init__.pyi
# __init__.pyi
# apps.pyi
# base_session.pyi
# exceptions.pyi
# middleware.pyi
# models.pyi
# serializers.pyi
# __init__.pyi
# base.pyi
# cache.pyi
# cached_db.pyi
# db.pyi
# file.pyi
# signed_cookies.pyi
# __init__.pyi
# __init__.pyi
# clearsessions.pyi
# __init__.pyi
# __init__.pyi
# apps.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# ping_google.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# management.pyi
# managers.pyi
# middleware.pyi
# models.pyi
# requests.pyi
# shortcuts.pyi
# __init__.pyi
# __init__.pyi
# apps.pyi
# checks.pyi
# finders.pyi
# handlers.pyi
# storage.pyi
# testing.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# collectstatic.pyi
# findstatic.pyi
# runserver.pyi
# __init__.pyi
# apps.pyi
# views.pyi
# __init__.pyi
# asgi.pyi
# exceptions.pyi
# paginator.pyi
# signals.pyi
# signing.pyi
# validators.pyi
# wsgi.pyi
# __init__.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# db.pyi
# dummy.pyi
# filebased.pyi
# locmem.pyi
# memcached.pyi
# __init__.pyi
# async_checks.pyi
# caches.pyi
# database.pyi
# messages.pyi
# model_checks.pyi
# registry.pyi
# templates.pyi
# translation.pyi
# urls.pyi
# __init__.pyi
# __init__.pyi
# base.pyi
# csrf.pyi
# sessions.pyi
# __init__.pyi
# base.pyi
# images.pyi
# locks.pyi
# move.pyi
# storage.pyi
# temp.pyi
# uploadedfile.pyi
# uploadhandler.pyi
# utils.pyi
# __init__.pyi
# asgi.pyi
# base.pyi
# exception.pyi
# wsgi.pyi
# __init__.pyi
# message.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# console.pyi
# dummy.pyi
# filebased.pyi
# locmem.pyi
# smtp.pyi
# __init__.pyi
# base.pyi
# color.pyi
# sql.pyi
# templates.pyi
# utils.pyi
# __init__.pyi
# check.pyi
# compilemessages.pyi
# createcachetable.pyi
# dbshell.pyi
# diffsettings.pyi
# dumpdata.pyi
# flush.pyi
# inspectdb.pyi
# loaddata.pyi
# makemessages.pyi
# makemigrations.pyi
# migrate.pyi
# runserver.pyi
# sendtestemail.pyi
# shell.pyi
# showmigrations.pyi
# sqlflush.pyi
# sqlmigrate.pyi
# sqlsequencereset.pyi
# squashmigrations.pyi
# startapp.pyi
# startproject.pyi
# test.pyi
# testserver.pyi
# __init__.pyi
# base.pyi
# json.pyi
# jsonl.pyi
# python.pyi
# pyyaml.pyi
# xml_serializer.pyi
# __init__.pyi
# basehttp.pyi
# __init__.pyi
# transaction.pyi
# utils.pyi
# __init__.pyi
# ddl_references.pyi
# signals.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# client.pyi
# creation.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# validation.pyi
# __init__.pyi
# base.pyi
# features.pyi
# __init__.pyi
# base.pyi
# client.pyi
# compiler.pyi
# creation.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# validation.pyi
# __init__.pyi
# base.pyi
# client.pyi
# creation.pyi
# features.pyi
# functions.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# utils.pyi
# validation.pyi
# __init__.pyi
# base.pyi
# client.pyi
# creation.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# test_import_all.yml
# __init__.pyi
# base.pyi
# client.pyi
# creation.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# autodetector.pyi
# exceptions.pyi
# executor.pyi
# graph.pyi
# loader.pyi
# migration.pyi
# optimizer.pyi
# questioner.pyi
# recorder.pyi
# serializer.pyi
# state.pyi
# utils.pyi
# writer.pyi
# __init__.pyi
# base.pyi
# fields.pyi
# models.pyi
# special.pyi
# utils.pyi
# __init__.pyi
# aggregates.pyi
# base.pyi
# constants.pyi
# constraints.pyi
# deletion.pyi
# enums.pyi
# expressions.pyi
# indexes.pyi
# lookups.pyi
# manager.pyi
# options.pyi
# query.pyi
# query_utils.pyi
# signals.pyi
# utils.pyi
# __init__.pyi
# files.pyi
# json.pyi
# mixins.pyi
# proxy.pyi
# related.pyi
# related_descriptors.pyi
# related_lookups.pyi
# reverse_related.pyi
# __init__.pyi
# comparison.pyi
# datetime.pyi
# math.pyi
# mixins.pyi
# text.pyi
# window.pyi
# __init__.pyi
# compiler.pyi
# constants.pyi
# datastructures.pyi
# query.pyi
# subqueries.pyi
# where.pyi
# __init__.pyi
# dispatcher.pyi
# __init__.pyi
# boundfield.pyi
# fields.pyi
# forms.pyi
# formsets.pyi
# models.pyi
# renderers.pyi
# utils.pyi
# widgets.pyi
# __init__.pyi
# cookie.pyi
# multipartparser.pyi
# request.pyi
# response.pyi
# __init__.pyi
# cache.pyi
# clickjacking.pyi
# common.pyi
# csrf.pyi
# gzip.pyi
# http.pyi
# locale.pyi
# security.pyi
# __init__.pyi
# base.pyi
# context.pyi
# context_processors.pyi
# defaultfilters.pyi
# defaulttags.pyi
# engine.pyi
# exceptions.pyi
# library.pyi
# loader.pyi
# loader_tags.pyi
# response.pyi
# smartif.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# django.pyi
# dummy.pyi
# jinja2.pyi
# utils.pyi
# __init__.pyi
# app_directories.pyi
# base.pyi
# cached.pyi
# filesystem.pyi
# locmem.pyi
# __init__.pyi
# cache.pyi
# i18n.pyi
# l10n.pyi
# static.pyi
# tz.pyi
# __init__.pyi
# client.pyi
# html.pyi
# runner.pyi
# selenium.pyi
# signals.pyi
# testcases.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# conf.pyi
# converters.pyi
# exceptions.pyi
# resolvers.pyi
# utils.pyi
# __init__.pyi
# archive.pyi
# asyncio.pyi
# autoreload.pyi
# baseconv.pyi
# cache.pyi
# connection.pyi
# crypto.pyi
# datastructures.pyi
# dateformat.pyi
# dateparse.pyi
# dates.pyi
# datetime_safe.pyi
# deconstruct.pyi
# decorators.pyi
# deprecation.pyi
# duration.pyi
# encoding.pyi
# feedgenerator.pyi
# formats.pyi
# functional.pyi
# hashable.pyi
# html.pyi
# http.pyi
# inspect.pyi
# ipv6.pyi
# itercompat.pyi
# jslex.pyi
# log.pyi
# lorem_ipsum.pyi
# module_loading.pyi
# numberformat.pyi
# regex_helper.pyi
# safestring.pyi
# termcolors.pyi
# text.pyi
# timesince.pyi
# timezone.pyi
# topological_sort.pyi
# tree.pyi
# version.pyi
# xmlutils.pyi
# _os.pyi
# __init__.pyi
# reloader.pyi
# template.pyi
# trans_null.pyi
# trans_real.pyi
# __init__.pyi
# csrf.pyi
# debug.pyi
# defaults.pyi
# i18n.pyi
# static.pyi
# __init__.pyi
# cache.pyi
# clickjacking.pyi
# common.pyi
# csrf.pyi
# debug.pyi
# gzip.pyi
# http.pyi
# vary.pyi
# __init__.pyi
# base.pyi
# dates.pyi
# detail.pyi
# edit.pyi
# list.pyi
# __init__.pyi
# core.pyi
# logger.pyi
# py.typed
# registration.pyi
# box.pyi
# dict.pyi
# discrete.pyi
# multi_binary.pyi
# multi_discrete.pyi
# space.pyi
# tuple.pyi
# utils.pyi
# async_vector_env.pyi
# sync_vector_env.pyi
# vector_env.pyi
# __init__.pyi
# time_limit.pyi
# exceptions.pyi
# functions.pyi
# parser.pyi
# visitor.pyi
# __init__.pyi
# afm.pyi
# animation.pyi
# artist.pyi
# axis.pyi
# backend_bases.pyi
# backend_managers.pyi
# backend_tools.pyi
# bezier.pyi
# blocking_input.pyi
# category.pyi
# cm.pyi
# collections.pyi
# colorbar.pyi
# colors.pyi
# container.pyi
# contour.pyi
# dates.pyi
# docstring.pyi
# dviread.pyi
# figure.pyi
# fontconfig_pattern.pyi
# font_manager.pyi
# ft2font.pyi
# gridspec.pyi
# image.pyi
# legend.pyi
# legend_handler.pyi
# lines.pyi
# markers.pyi
# mathtext.pyi
# mlab.pyi
# offsetbox.pyi
# patches.pyi
# path.pyi
# patheffects.pyi
# pyplot.pyi
# quiver.pyi
# rcsetup.pyi
# sankey.pyi
# scale.pyi
# spines.pyi
# stackplot.pyi
# streamplot.pyi
# streamploy.pyi
# table.pyi
# text.pyi
# textmanager.pyi
# textpath.pyi
# ticker.pyi
# tight_layout.pyi
# transforms.pyi
# type1font.pyi
# units.pyi
# widgets.pyi
# _typing.pyi
# __init__.pyi
# _axes.pyi
# _base.pyi
# _secondary_axes.pyi
# _subplots.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# plot_directive.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# commit.txt
# LICENSE
# __init__.pyi
# cell.pyi
# text.pyi
# _writer.pyi
# __init__.pyi
# axis.pyi
# __init__.pyi
# drawings.pyi
# excel.pyi
# strings.pyi
# workbook.pyi
# __init__.pyi
# alignment.pyi
# borders.pyi
# colors.pyi
# differential.pyi
# fills.pyi
# fonts.pyi
# named_styles.pyi
# numbers.pyi
# protection.pyi
# styleable.pyi
# __init__.pyi
# cell.pyi
# escape.py
# escape.pyi
# formulas.pyi
# __init__.pyi
# child.pyi
# workbook.pyi
# __init__.pyi
# copier.pyi
# worksheet.pyi
# _reader.pyi
# _writer.pyi
# __init__.pyi
# __init__.pyi
# testing.pyi
# _testing.pyi
# _typing.pyi
# _version.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# pickle_compat.pyi
# _optional.pyi
# __init__.pyi
# __init__.pyi
# accessor.pyi
# algorithms.pyi
# api.pyi
# apply.pyi
# arraylike.pyi
# base.pyi
# common.pyi
# config_init.pyi
# construction.pyi
# frame.pyi
# generic.pyi
# index.pyi
# indexers.pyi
# indexing.pyi
# missing.pyi
# nanops.pyi
# resample.pyi
# series.pyi
# sorting.pyi
# strings.pyi
# __init__.pyi
# base.pyi
# boolean.pyi
# categorical.pyi
# datetimelike.pyi
# datetimes.pyi
# integer.pyi
# interval.pyi
# masked.pyi
# numpy_.pyi
# period.pyi
# string_.pyi
# timedeltas.pyi
# _arrow_utils.pyi
# _ranges.pyi
# __init__.pyi
# accessor.pyi
# array.pyi
# dtype.pyi
# scipy_sparse.pyi
# __init__.pyi
# align.pyi
# api.pyi
# check.pyi
# common.pyi
# engines.pyi
# eval.pyi
# expr.pyi
# expressions.pyi
# ops.pyi
# parsing.pyi
# pytables.pyi
# scope.pyi
# __init__.pyi
# api.pyi
# base.pyi
# cast.pyi
# common.pyi
# concat.pyi
# dtypes.pyi
# generic.pyi
# inference.pyi
# missing.pyi
# __init__.pyi
# base.pyi
# categorical.pyi
# generic.pyi
# groupby.pyi
# grouper.pyi
# ops.pyi
# __init__.pyi
# accessors.pyi
# api.pyi
# base.pyi
# category.pyi
# datetimelike.pyi
# datetimes.pyi
# extension.pyi
# frozen.pyi
# interval.pyi
# multi.pyi
# numeric.pyi
# period.pyi
# range.pyi
# timedeltas.pyi
# __init__.pyi
# blocks.pyi
# concat.pyi
# construction.pyi
# managers.pyi
# __init__.pyi
# array_ops.pyi
# common.pyi
# dispatch.pyi
# docstrings.pyi
# invalid.pyi
# mask_ops.pyi
# methods.pyi
# missing.pyi
# roperator.pyi
# __init__.pyi
# api.pyi
# concat.pyi
# melt.pyi
# merge.pyi
# pivot.pyi
# reshape.pyi
# tile.pyi
# util.pyi
# __init__.pyi
# api.pyi
# __init__.pyi
# datetimes.pyi
# numeric.pyi
# timedeltas.pyi
# __init__.pyi
# hashing.pyi
# __init__.pyi
# common.pyi
# ewm.pyi
# expanding.pyi
# indexers.pyi
# numba_.pyi
# rolling.pyi
# __init__.pyi
# __init__.pyi
# api.pyi
# clipboards.pyi
# common.pyi
# date_converters.pyi
# feather_format.pyi
# gbq.pyi
# gcs.pyi
# html.pyi
# orc.pyi
# parquet.pyi
# parsers.pyi
# pickle.pyi
# pytables.pyi
# s3.pyi
# spss.pyi
# sql.pyi
# stata.pyi
# xml.pyi
# __init__.pyi
# __init__.pyi
# _base.pyi
# _util.pyi
# __init__.pyi
# console.pyi
# css.pyi
# csvs.pyi
# excel.pyi
# format.pyi
# html.pyi
# latex.pyi
# printing.pyi
# style.pyi
# __init__.pyi
# _json.pyi
# _normalize.pyi
# _table_schema.pyi
# __init__.pyi
# sas7bdat.pyi
# sasreader.pyi
# sas_constants.pyi
# sas_xport.pyi
# __init__.pyi
# _core.pyi
# _misc.pyi
# __init__.pyi
# boxplot.pyi
# compat.pyi
# converter.pyi
# core.pyi
# hist.pyi
# misc.pyi
# style.pyi
# timeseries.pyi
# tools.pyi
# __init__.pyi
# api.pyi
# frequencies.pyi
# offsets.pyi
# __init__.pyi
# _decorators.pyi
# _depr_module.pyi
# _doctools.pyi
# _exceptions.pyi
# _print_versions.pyi
# _tester.pyi
# _test_decorators.pyi
# _validators.pyi
# __init__.pyi
# config.pyi
# __init__.pyi
# indexing.pyi
# interval.pyi
# json.pyi
# lib.pyi
# missing.pyi
# ops_dispatch.pyi
# properties.pyi
# sparse.pyi
# __init__.pyi
# base.pyi
# ccalendar.pyi
# conversion.pyi
# dtypes.pyi
# nattype.pyi
# np_datetime.pyi
# offsets.pyi
# parsing.pyi
# period.pyi
# strptime.pyi
# timedeltas.pyi
# timestamps.pyi
# tzconversion.pyi
# vectorized.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# dde.pyi
# py.typed
# win32ui.pyi
# win32uiole.pyi
# py.typed
# _hierarchy.pyi
# _optimal_leaf_ordering.pyi
# _vq.pyi
# pypocketfft.pyi
# convolve.pyi
# lsoda.pyi
# vode.pyi
# _dop.pyi
# _odepack.pyi
# _quadpack.pyi
# _test_multivariate.pyi
# _test_odeint_banded.pyi
# dfitpack.pyi
# interpnd.pyi
# _bspl.pyi
# _fitpack.pyi
# _ppoly.pyi
# _test_fortran.pyi
# mio5_utils.pyi
# mio_utils.pyi
# streams.pyi
# cython_blas.pyi
# cython_lapack.pyi
# _decomp_update.pyi
# _fblas.pyi
# _flapack.pyi
# _flinalg.pyi
# _interpolative.pyi
# _matfuncs_sqrtm_triu.pyi
# _solve_toeplitz.pyi
# _ctest.pyi
# _cytest.pyi
# _nd_image.pyi
# _ni_label.pyi
# __odrpack.pyi
# minpack2.pyi
# moduleTNC.pyi
# _bglu_dense.pyi
# _cobyla.pyi
# _group_columns.pyi
# _lbfgsb.pyi
# _lsap_module.pyi
# _minpack.pyi
# _slsqp.pyi
# _zeros.pyi
# __nnls.pyi
# _zeros.pyi
# _highs_constants.pyi
# _highs_wrapper.pyi
# _mpswriter.pyi
# givens_elimination.pyi
# _trlib.pyi
# sigtools.pyi
# spline.pyi
# _max_len_seq_inner.pyi
# _peak_finding_utils.pyi
# _sosfilt.pyi
# _spectral.pyi
# _upfirdn_apply.pyi
# _csparsetools.pyi
# _sparsetools.pyi
# _flow.pyi
# _matching.pyi
# _min_spanning_tree.pyi
# _reordering.pyi
# _shortest_path.pyi
# _tools.pyi
# _traversal.pyi
# _superlu.pyi
# _arpack.pyi
# _iterative.pyi
# lobpcg.pyi
# ckdtree.pyi
# qhull.pyi
# _distance_wrap.pyi
# _hausdorff.pyi
# _voronoi.pyi
# rotation.pyi
# cython_special.pyi
# specfun.pyi
# _comb.pyi
# _ellip_harm_2.pyi
# _test_round.pyi
# _ufuncs.pyi
# _ufuncs_cxx.pyi
# mvn.pyi
# statlib.pyi
# _stats.pyi
# messagestream.pyi
# _ccallback_c.pyi
# _fpumode.pyi
# _test_ccallback.pyi
# _test_deprecation_call.pyi
# _test_deprecation_def.pyi
# _uarray.pyi
# palettes.pyi
# py.typed
# py.typed
# _base.pyi
# _pca.pyi
# _lobpcg.pyi
# spectral_embedding.pyi
# validation.pyi
# py.typed
# evalf.pyi
# power.pyi
# powsimp.pyi
# simplify.pyi
# py.typed
# configuration_auto.pyi
# tokenization_auto.pyi
# mmapfile.pyi
# odbc.pyi
# perfmon.pyi
# py.typed
# servicemanager.pyi
# timer.pyi
# win2kras.pyi
# win32api.pyi
# win32clipboard.pyi
# win32console.pyi
# win32cred.pyi
# win32crypt.pyi
# win32event.pyi
# win32evtlog.pyi
# win32file.pyi
# win32gui.pyi
# win32help.pyi
# win32inet.pyi
# win32job.pyi
# win32lz.pyi
# win32net.pyi
# win32pdh.pyi
# win32pipe.pyi
# win32print.pyi
# win32process.pyi
# win32profile.pyi
# win32ras.pyi
# win32security.pyi
# win32service.pyi
# win32trace.pyi
# win32transaction.pyi
# win32ts.pyi
# win32wnet.pyi
# winxpgui.pyi
# py.typed
# adsi.pyi
# authorization.pyi
# axcontrol.pyi
# axscript.pyi
# bits.pyi
# directsound.pyi
# ifilter.pyi
# exchange.pyi
# mapi.pyi
# propsys.pyi
# shell.pyi
# taskscheduler.pyi
# libonnxruntime.1.11.0.dylib
# onnxruntime_binding.node
# libonnxruntime.1.11.0.dylib
# onnxruntime_binding.node
# libonnxruntime.so.1.11.0
# onnxruntime_binding.node
# onnxruntime.dll
# onnxruntime_binding.node
# onnxruntime_providers_shared.dll
# pyrightconfig.schema.json
# scrape_module.py
# commit.txt
# LICENSE
# README.md
# abc.pyi
# aifc.pyi
# antigravity.pyi
# argparse.pyi
# array.pyi
# ast.pyi
# asynchat.pyi
# asyncore.pyi
# atexit.pyi
# audioop.pyi
# base64.pyi
# bdb.pyi
# binascii.pyi
# binhex.pyi
# bisect.pyi
# builtins.pyi
# bz2.pyi
# calendar.pyi
# cgi.pyi
# cgitb.pyi
# chunk.pyi
# cmath.pyi
# cmd.pyi
# code.pyi
# codecs.pyi
# codeop.pyi
# colorsys.pyi
# compileall.pyi
# configparser.pyi
# contextlib.pyi
# contextvars.pyi
# copy.pyi
# copyreg.pyi
# cProfile.pyi
# crypt.pyi
# csv.pyi
# dataclasses.pyi
# datetime.pyi
# decimal.pyi
# difflib.pyi
# dis.pyi
# doctest.pyi
# dummy_threading.pyi
# enum.pyi
# errno.pyi
# faulthandler.pyi
# fcntl.pyi
# filecmp.pyi
# fileinput.pyi
# fnmatch.pyi
# formatter.pyi
# fractions.pyi
# ftplib.pyi
# functools.pyi
# gc.pyi
# genericpath.pyi
# getopt.pyi
# getpass.pyi
# gettext.pyi
# glob.pyi
# graphlib.pyi
# grp.pyi
# gzip.pyi
# hashlib.pyi
# heapq.pyi
# hmac.pyi
# imaplib.pyi
# imghdr.pyi
# imp.pyi
# inspect.pyi
# io.pyi
# ipaddress.pyi
# itertools.pyi
# keyword.pyi
# linecache.pyi
# locale.pyi
# lzma.pyi
# macpath.pyi
# macurl2path.pyi
# mailbox.pyi
# mailcap.pyi
# marshal.pyi
# math.pyi
# mimetypes.pyi
# mmap.pyi
# modulefinder.pyi
# msvcrt.pyi
# netrc.pyi
# nis.pyi
# nntplib.pyi
# ntpath.pyi
# nturl2path.pyi
# numbers.pyi
# opcode.pyi
# operator.pyi
# optparse.pyi
# ossaudiodev.pyi
# parser.pyi
# pathlib.pyi
# pdb.pyi
# pickle.pyi
# pickletools.pyi
# pipes.pyi
# pkgutil.pyi
# platform.pyi
# plistlib.pyi
# poplib.pyi
# posix.pyi
# posixpath.pyi
# pprint.pyi
# profile.pyi
# pstats.pyi
# pty.pyi
# pwd.pyi
# pyclbr.pyi
# pydoc.pyi
# py_compile.pyi
# queue.pyi
# quopri.pyi
# random.pyi
# re.pyi
# readline.pyi
# reprlib.pyi
# resource.pyi
# rlcompleter.pyi
# runpy.pyi
# sched.pyi
# secrets.pyi
# select.pyi
# selectors.pyi
# shelve.pyi
# shlex.pyi
# shutil.pyi
# signal.pyi
# site.pyi
# smtpd.pyi
# smtplib.pyi
# sndhdr.pyi
# socket.pyi
# socketserver.pyi
# spwd.pyi
# sre_compile.pyi
# sre_constants.pyi
# sre_parse.pyi
# ssl.pyi
# stat.pyi
# statistics.pyi
# string.pyi
# stringprep.pyi
# struct.pyi
# subprocess.pyi
# sunau.pyi
# symbol.pyi
# symtable.pyi
# sys.pyi
# sysconfig.pyi
# syslog.pyi
# tabnanny.pyi
# tarfile.pyi
# telnetlib.pyi
# tempfile.pyi
# termios.pyi
# textwrap.pyi
# this.pyi
# threading.pyi
# time.pyi
# timeit.pyi
# token.pyi
# tokenize.pyi
# tomllib.pyi
# trace.pyi
# traceback.pyi
# tracemalloc.pyi
# tty.pyi
# turtle.pyi
# types.pyi
# typing.pyi
# typing_extensions.pyi
# unicodedata.pyi
# uu.pyi
# uuid.pyi
# VERSIONS
# warnings.pyi
# wave.pyi
# weakref.pyi
# webbrowser.pyi
# winreg.pyi
# winsound.pyi
# xdrlib.pyi
# xxlimited.pyi
# zipapp.pyi
# zipfile.pyi
# zipimport.pyi
# zlib.pyi
# _ast.pyi
# _bisect.pyi
# _bootlocale.pyi
# _codecs.pyi
# _collections_abc.pyi
# _compat_pickle.pyi
# _compression.pyi
# _csv.pyi
# _curses.pyi
# _decimal.pyi
# _dummy_thread.pyi
# _dummy_threading.pyi
# _heapq.pyi
# _imp.pyi
# _json.pyi
# _markupbase.pyi
# _msi.pyi
# _operator.pyi
# _osx_support.pyi
# _posixsubprocess.pyi
# _pydecimal.pyi
# _py_abc.pyi
# _random.pyi
# _sitebuiltins.pyi
# _socket.pyi
# _stat.pyi
# _thread.pyi
# _threading_local.pyi
# _tkinter.pyi
# _tracemalloc.pyi
# _warnings.pyi
# _weakref.pyi
# _weakrefset.pyi
# _winapi.pyi
# __future__.pyi
# __main__.pyi
# base_events.pyi
# base_futures.pyi
# base_subprocess.pyi
# base_tasks.pyi
# compat.pyi
# constants.pyi
# coroutines.pyi
# events.pyi
# exceptions.pyi
# format_helpers.pyi
# futures.pyi
# locks.pyi
# log.pyi
# mixins.pyi
# proactor_events.pyi
# protocols.pyi
# queues.pyi
# runners.pyi
# selector_events.pyi
# sslproto.pyi
# staggered.pyi
# streams.pyi
# subprocess.pyi
# taskgroups.pyi
# tasks.pyi
# threads.pyi
# timeouts.pyi
# transports.pyi
# trsock.pyi
# unix_events.pyi
# windows_events.pyi
# windows_utils.pyi
# __init__.pyi
# abc.pyi
# __init__.pyi
# __init__.pyi
# process.pyi
# thread.pyi
# _base.pyi
# __init__.pyi
# util.pyi
# wintypes.pyi
# __init__.pyi
# ascii.pyi
# panel.pyi
# textpad.pyi
# __init__.pyi
# dumb.pyi
# gnu.pyi
# ndbm.pyi
# __init__.pyi
# archive_util.pyi
# bcppcompiler.pyi
# ccompiler.pyi
# cmd.pyi
# config.pyi
# core.pyi
# cygwinccompiler.pyi
# debug.pyi
# dep_util.pyi
# dir_util.pyi
# dist.pyi
# errors.pyi
# extension.pyi
# fancy_getopt.pyi
# filelist.pyi
# file_util.pyi
# log.pyi
# msvccompiler.pyi
# spawn.pyi
# sysconfig.pyi
# text_file.pyi
# unixccompiler.pyi
# util.pyi
# version.pyi
# __init__.pyi
# bdist.pyi
# bdist_dumb.pyi
# bdist_msi.pyi
# bdist_packager.pyi
# bdist_rpm.pyi
# bdist_wininst.pyi
# build.pyi
# build_clib.pyi
# build_ext.pyi
# build_py.pyi
# build_scripts.pyi
# check.pyi
# clean.pyi
# config.pyi
# install.pyi
# install_data.pyi
# install_egg_info.pyi
# install_headers.pyi
# install_lib.pyi
# install_scripts.pyi
# register.pyi
# sdist.pyi
# upload.pyi
# __init__.pyi
# base64mime.pyi
# charset.pyi
# contentmanager.pyi
# encoders.pyi
# errors.pyi
# feedparser.pyi
# generator.pyi
# header.pyi
# headerregistry.pyi
# iterators.pyi
# message.pyi
# parser.pyi
# policy.pyi
# quoprimime.pyi
# utils.pyi
# _header_value_parser.pyi
# __init__.pyi
# application.pyi
# audio.pyi
# base.pyi
# image.pyi
# message.pyi
# multipart.pyi
# nonmultipart.pyi
# text.pyi
# __init__.pyi
# utf_8.pyi
# utf_8_sig.pyi
# __init__.pyi
# __init__.pyi
# entities.pyi
# parser.pyi
# __init__.pyi
# client.pyi
# cookiejar.pyi
# cookies.pyi
# server.pyi
# __init__.pyi
# abc.pyi
# machinery.pyi
# resources.pyi
# util.pyi
# __init__.pyi
# _meta.pyi
# __init__.pyi
# decoder.pyi
# encoder.pyi
# tool.pyi
# __init__.pyi
# pygram.pyi
# pytree.pyi
# refactor.pyi
# __init__.pyi
# driver.pyi
# grammar.pyi
# literals.pyi
# parse.pyi
# pgen.pyi
# token.pyi
# tokenize.pyi
# __init__.pyi
# config.pyi
# handlers.pyi
# __init__.pyi
# schema.pyi
# sequence.pyi
# text.pyi
# __init__.pyi
# connection.pyi
# context.pyi
# managers.pyi
# pool.pyi
# process.pyi
# queues.pyi
# reduction.pyi
# sharedctypes.pyi
# shared_memory.pyi
# spawn.pyi
# synchronize.pyi
# __init__.pyi
# connection.pyi
# __init__.pyi
# path.pyi
# __init__.pyi
# topics.pyi
# __init__.pyi
# errors.pyi
# model.pyi
# __init__.pyi
# dbapi2.pyi
# __init__.pyi
# colorchooser.pyi
# commondialog.pyi
# constants.pyi
# dialog.pyi
# dnd.pyi
# filedialog.pyi
# font.pyi
# messagebox.pyi
# scrolledtext.pyi
# simpledialog.pyi
# tix.pyi
# ttk.pyi
# __init__.pyi
# async_case.pyi
# case.pyi
# loader.pyi
# main.pyi
# mock.pyi
# result.pyi
# runner.pyi
# signals.pyi
# suite.pyi
# util.pyi
# _log.pyi
# __init__.pyi
# error.pyi
# parse.pyi
# request.pyi
# response.pyi
# robotparser.pyi
# __init__.pyi
# __init__.pyi
# handlers.pyi
# headers.pyi
# simple_server.pyi
# types.pyi
# util.pyi
# validate.pyi
# __init__.pyi
# __init__.pyi
# domreg.pyi
# expatbuilder.pyi
# minicompat.pyi
# minidom.pyi
# NodeFilter.pyi
# pulldom.pyi
# xmlbuilder.pyi
# __init__.pyi
# cElementTree.pyi
# ElementInclude.pyi
# ElementPath.pyi
# ElementTree.pyi
# __init__.pyi
# __init__.pyi
# errors.pyi
# model.pyi
# __init__.pyi
# handler.pyi
# saxutils.pyi
# xmlreader.pyi
# __init__.pyi
# client.pyi
# server.pyi
# __init__.pyi
# __init__.pyi
# dbapi.pyi
# README.md
# wsgi.pyi
# xml.pyi
# __init__.pyi
# METADATA.toml
# base.pyi
# os.pyi
# ospath.pyi
# __init__.pyi
# binary.pyi
# text.pyi
# __init__.pyi
# METADATA.toml
# __init__.pyi
# appdirs.pyi
# METADATA.toml
# METADATA.toml
# __init__.pyi
# METADATA.toml
# sdk_config.pyi
# version.pyi
# __init__.pyi
# async_context.pyi
# async_recorder.pyi
# context.pyi
# daemon_config.pyi
# lambda_launcher.pyi
# patcher.pyi
# recorder.pyi
# __init__.pyi
# udp_emitter.pyi
# __init__.pyi
# exceptions.pyi
# __init__.pyi
# default_dynamic_naming.pyi
# dummy_entities.pyi
# entity.pyi
# facade_segment.pyi
# http.pyi
# noop_traceid.pyi
# segment.pyi
# subsegment.pyi
# throwable.pyi
# traceid.pyi
# trace_header.pyi
# __init__.pyi
# ec2_plugin.pyi
# ecs_plugin.pyi
# elasticbeanstalk_plugin.pyi
# utils.pyi
# __init__.pyi
# connector.pyi
# reservoir.pyi
# rule_cache.pyi
# rule_poller.pyi
# sampler.pyi
# sampling_rule.pyi
# target_poller.pyi
# __init__.pyi
# reservoir.pyi
# sampler.pyi
# sampling_rule.pyi
# __init__.pyi
# default_streaming.pyi
# __init__.pyi
# atomic_counter.pyi
# compat.pyi
# conversion.pyi
# search_pattern.pyi
# stacktrace.pyi
# __init__.pyi
# METADATA.toml
# core.pyi
# dates.pyi
# languages.pyi
# lists.pyi
# localedata.pyi
# numbers.pyi
# plural.pyi
# support.pyi
# units.pyi
# util.pyi
# __init__.pyi
# _unix.pyi
# _win32.pyi
# __init__.pyi
# catalog.pyi
# checkers.pyi
# extract.pyi
# frontend.pyi
# jslexer.pyi
# mofile.pyi
# plurals.pyi
# pofile.pyi
# __init__.pyi
# METADATA.toml
# __init__.pyi
# __init__.pyi
# METADATA.toml
# dammit.pyi
# diagnose.pyi
# element.pyi
# formatter.pyi
# __init__.pyi
# _html5lib.pyi
# _htmlparser.pyi
# _lxml.pyi
# __init__.pyi
# METADATA.toml
# callbacks.pyi
# css_sanitizer.pyi
# html5lib_shim.pyi
# linkifier.pyi
# sanitizer.pyi
# __init__.pyi
# METADATA.toml
# auth.pyi
# auth_handler.pyi
# compat.pyi
# connection.pyi
# exception.pyi
# plugin.pyi
# regioninfo.pyi
# utils.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# exceptions.pyi
# layer1.pyi
# __init__.pyi
# acl.pyi
# bucket.pyi
# bucketlistresultset.pyi
# bucketlogging.pyi
# connection.pyi
# cors.pyi
# deletemarker.pyi
# key.pyi
# keyfile.pyi
# lifecycle.pyi
# multidelete.pyi
# multipart.pyi
# prefix.pyi
# tagging.pyi
# user.pyi
# website.pyi
# __init__.pyi
# METADATA.toml
# account_updater_daily_report.pyi
# ach_mandate.pyi
# address.pyi
# address_gateway.pyi
# add_on.pyi
# add_on_gateway.pyi
# amex_express_checkout_card.pyi
# android_pay_card.pyi
# apple_pay_card.pyi
# apple_pay_gateway.pyi
# apple_pay_options.pyi
# attribute_getter.pyi
# authorization_adjustment.pyi
# bin_data.pyi
# braintree_gateway.pyi
# client_token.pyi
# client_token_gateway.pyi
# configuration.pyi
# connected_merchant_paypal_status_changed.pyi
# connected_merchant_status_transitioned.pyi
# credentials_parser.pyi
# credit_card.pyi
# credit_card_gateway.pyi
# credit_card_verification.pyi
# credit_card_verification_gateway.pyi
# credit_card_verification_search.pyi
# customer.pyi
# customer_gateway.pyi
# customer_search.pyi
# descriptor.pyi
# disbursement.pyi
# disbursement_detail.pyi
# discount.pyi
# discount_gateway.pyi
# dispute.pyi
# dispute_gateway.pyi
# dispute_search.pyi
# document_upload.pyi
# document_upload_gateway.pyi
# environment.pyi
# errors.pyi
# error_codes.pyi
# error_result.pyi
# europe_bank_account.pyi
# facilitated_details.pyi
# facilitator_details.pyi
# granted_payment_instrument_update.pyi
# iban_bank_account.pyi
# ids_search.pyi
# local_payment.pyi
# local_payment_completed.pyi
# local_payment_reversed.pyi
# masterpass_card.pyi
# merchant.pyi
# merchant_account_gateway.pyi
# merchant_gateway.pyi
# modification.pyi
# oauth_access_revocation.pyi
# oauth_credentials.pyi
# oauth_gateway.pyi
# paginated_collection.pyi
# paginated_result.pyi
# partner_merchant.pyi
# payment_instrument_type.pyi
# payment_method.pyi
# payment_method_gateway.pyi
# payment_method_nonce.pyi
# payment_method_nonce_gateway.pyi
# payment_method_parser.pyi
# paypal_account.pyi
# paypal_account_gateway.pyi
# paypal_here.pyi
# plan.pyi
# plan_gateway.pyi
# processor_response_types.pyi
# resource.pyi
# resource_collection.pyi
# revoked_payment_method_metadata.pyi
# risk_data.pyi
# samsung_pay_card.pyi
# search.pyi
# settlement_batch_summary.pyi
# settlement_batch_summary_gateway.pyi
# signature_service.pyi
# status_event.pyi
# subscription.pyi
# subscription_details.pyi
# subscription_gateway.pyi
# subscription_search.pyi
# subscription_status_event.pyi
# successful_result.pyi
# testing_gateway.pyi
# three_d_secure_info.pyi
# transaction.pyi
# transaction_amounts.pyi
# transaction_details.pyi
# transaction_gateway.pyi
# transaction_line_item.pyi
# transaction_line_item_gateway.pyi
# transaction_search.pyi
# unknown_payment_method.pyi
# us_bank_account.pyi
# us_bank_account_gateway.pyi
# us_bank_account_verification.pyi
# us_bank_account_verification_gateway.pyi
# us_bank_account_verification_search.pyi
# validation_error.pyi
# validation_error_collection.pyi
# venmo_account.pyi
# version.pyi
# visa_checkout_card.pyi
# webhook_notification.pyi
# webhook_notification_gateway.pyi
# webhook_testing.pyi
# webhook_testing_gateway.pyi
# __init__.pyi
# evidence.pyi
# paypal_message.pyi
# status_history.pyi
# __init__.pyi
# authentication_error.pyi
# authorization_error.pyi
# braintree_error.pyi
# configuration_error.pyi
# gateway_timeout_error.pyi
# invalid_challenge_error.pyi
# invalid_signature_error.pyi
# not_found_error.pyi
# request_timeout_error.pyi
# server_error.pyi
# service_unavailable_error.pyi
# too_many_requests_error.pyi
# unexpected_error.pyi
# upgrade_required_error.pyi
# __init__.pyi
# connection_error.pyi
# invalid_response_error.pyi
# timeout_error.pyi
# __init__.pyi
# address_details.pyi
# business_details.pyi
# funding_details.pyi
# individual_details.pyi
# merchant_account.pyi
# __init__.pyi
# constants.pyi
# crypto.pyi
# datetime_parser.pyi
# generator.pyi
# graphql_client.pyi
# http.pyi
# parser.pyi
# xml_util.pyi
# __init__.pyi
# METADATA.toml
# func.pyi
# keys.pyi
# __init__.pyi
# METADATA.toml
# davclient.pyi
# objects.pyi
# __init__.pyi
# base.pyi
# cdav.pyi
# dav.pyi
# ical.pyi
# __init__.pyi
# error.pyi
# namespace.pyi
# url.pyi
# vcal.pyi
# __init__.pyi
# certifi.pyi
# METADATA.toml
# METADATA.toml
# enums.pyi
# langbulgarianmodel.pyi
# langcyrillicmodel.pyi
# langgreekmodel.pyi
# langhebrewmodel.pyi
# langhungarianmodel.pyi
# langthaimodel.pyi
# langturkishmodel.pyi
# universaldetector.pyi
# version.pyi
# __init__.pyi
# METADATA.toml
# main.pyi
# metadata.pyi
# renderer.pyi
# tokenizer.pyi
# __init__.pyi
# METADATA.toml
# __init__.pyi
# METADATA.toml
# ansi.pyi
# ansitowin32.pyi
# initialise.pyi
# win32.pyi
# winterm.pyi
# __init__.pyi
# METADATA.toml
# blocks.pyi
# cmark.pyi
# common.pyi
# dump.pyi
# entitytrans.pyi
# inlines.pyi
# main.pyi
# node.pyi
# normalize_reference.pyi
# __init__.pyi
# html.pyi
# renderer.pyi
# rst.pyi
# __init__.pyi
# contextvars.pyi
# METADATA.toml
# croniter.pyi
# METADATA.toml
# METADATA.toml
# exceptions.pyi
# fernet.pyi
# __init__.pyi
# __init__.pyi
# interfaces.pyi
# __init__.pyi
# __init__.pyi
# binding.pyi
# __init__.pyi
# cmac.pyi
# constant_time.pyi
# hashes.pyi
# hmac.pyi
# keywrap.pyi
# padding.pyi
# poly1305.pyi
# __init__.pyi
# dh.pyi
# dsa.pyi
# ec.pyi
# ed25519.pyi
# ed448.pyi
# padding.pyi
# rsa.pyi
# utils.pyi
# x25519.pyi
# x448.pyi
# __init__.pyi
# aead.pyi
# algorithms.pyi
# modes.pyi
# __init__.pyi
# concatkdf.pyi
# hkdf.pyi
# kbkdf.pyi
# pbkdf2.pyi
# scrypt.pyi
# x963kdf.pyi
# __init__.pyi
# pkcs12.pyi
# pkcs7.pyi
# __init__.pyi
# hotp.pyi
# totp.pyi
# __init__.pyi
# extensions.pyi
# oid.pyi
# __init__.pyi
# METADATA.toml
# conf.pyi
# date.pyi
# date_parser.pyi
# freshness_date_parser.pyi
# parser.pyi
# timezones.pyi
# timezone_parser.pyi
# __init__.pyi
# hijri.pyi
# hijri_parser.pyi
# jalali.pyi
# jalali_parser.pyi
# __init__.pyi
# languages_info.pyi
# __init__.pyi
# dictionary.pyi
# loader.pyi
# locale.pyi
# validation.pyi
# __init__.pyi
# detection.pyi
# search.pyi
# text_detection.pyi
# __init__.pyi
# strptime.pyi
# __init__.pyi
# settings.pyi
# __init__.pyi
# METADATA.toml
# __init__.pyi
# decorator.pyi
# METADATA.toml
# METADATA.toml
# classic.pyi
# sphinx.pyi
# __init__.pyi
# dj_database_url.pyi
# METADATA.toml
# docopt.pyi
# METADATA.toml
# METADATA.toml
# core.pyi
# examples.pyi
# frontend.pyi
# io.pyi
# nodes.pyi
# statemachine.pyi
# __init__.pyi
# __init__.pyi
# null.pyi
# recommonmark_wrapper.pyi
# __init__.pyi
# roles.pyi
# states.pyi
# __init__.pyi
# admonitions.pyi
# body.pyi
# html.pyi
# images.pyi
# misc.pyi
# parts.pyi
# references.pyi
# tables.pyi
# __init__.pyi
# doctree.pyi
# pep.pyi
# standalone.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# docutils_xml.pyi
# html4css1.pyi
# html5_polyglot.pyi
# latex2e.pyi
# manpage.pyi
# null.pyi
# odf_odt.pyi
# pep_html.pyi
# pseudoxml.pyi
# s5_html.pyi
# xetex.pyi
# __init__.pyi
# editdistance.pyi
# METADATA.toml
# METADATA.toml
# core.pyi
# __init__.pyi
# __init__.pyi
# entrypoints.pyi
# METADATA.toml
# first.pyi
# METADATA.toml
# flake8_2020.pyi
# METADATA.toml
# bugbear.pyi
# METADATA.toml
# flake8_builtins.pyi
# METADATA.toml
# flake8_docstrings.pyi
# METADATA.toml
# METADATA.toml
# plugin.pyi
# __init__.pyi
# assertions.pyi
# constants.pyi
# equiv_nodes.pyi
# __init__.pyi
# flake8_rst_docstrings.pyi
# METADATA.toml
# METADATA.toml
# __init__.pyi
# flake8_typing_imports.pyi
# METADATA.toml
# METADATA.toml
# core.pyi
# decorator.pyi
# extension.pyi
# version.pyi
# __init__.pyi
# METADATA.toml
# model.pyi
# utils.pyi
# __init__.pyi
# METADATA.toml
# actions.pyi
# deprecation.pyi
# enums.pyi
# errors.pyi
# fonts.pyi
# fpdf.pyi
# html.pyi
# image_parsing.pyi
# outline.pyi
# recorder.pyi
# structure_tree.pyi
# syntax.pyi
# template.pyi
# transitions.pyi
# ttfonts.pyi
# util.pyi
# __init__.pyi
# METADATA.toml
# api.pyi
# __init__.pyi
# frozendict.pyi
# METADATA.toml
# METADATA.toml
# events.pyi
# printing.pyi
# prompt.pyi
# types.pyi
# unwinder.pyi
# xmethod.pyi
# __init__.pyi
# METADATA.toml
# blobstore.pyi
# client.pyi
# context.pyi
# django_middleware.pyi
# exceptions.pyi
# global_cache.pyi
# key.pyi
# metadata.pyi
# model.pyi
# msgprop.pyi
# polymodel.pyi
# query.pyi
# stats.pyi
# tasklets.pyi
# utils.pyi
# _batch.pyi
# _cache.pyi
# _datastore_api.pyi
# _datastore_query.pyi
# _eventloop.pyi
# _options.pyi
# _transaction.pyi
# __init__.pyi
# METADATA.toml
# dbapi.pyi
# resultrow.pyi
# __init__.pyi
# METADATA.toml
# constants.pyi
# html5parser.pyi
# serializer.pyi
# _ihatexml.pyi
# _inputstream.pyi
# _tokenizer.pyi
# _utils.pyi
# __init__.pyi
# alphabeticalattributes.pyi
# base.pyi
# inject_meta_charset.pyi
# lint.pyi
# optionaltags.pyi
# sanitizer.pyi
# whitespace.pyi
# __init__.pyi
# genshi.pyi
# sax.pyi
# __init__.pyi
# base.pyi
# dom.pyi
# etree.pyi
# etree_lxml.pyi
# __init__.pyi
# base.pyi
# dom.pyi
# etree.pyi
# etree_lxml.pyi
# genshi.pyi
# __init__.pyi
# py.pyi
# _base.pyi
# __init__.pyi
# METADATA.toml
# auth.pyi
# certs.pyi
# error.pyi
# iri2uri.pyi
# socks.pyi
# __init__.pyi
# METADATA.toml
# case.pyi
# cli.pyi
# compat.pyi
# decorators.pyi
# deprecation.pyi
# prompts.pyi
# sphinx.pyi
# tables.pyi
# testing.pyi
# text.pyi
# usage.pyi
# __init__.pyi
# html.pyi
# spinners.pyi
# __init__.pyi
# METADATA.toml
# collection.pyi
# config.pyi
# context.pyi
# env.pyi
# exceptions.pyi
# executor.pyi
# loader.pyi
# main.pyi
# program.pyi
# runners.pyi
# tasks.pyi
# terminals.pyi
# util.pyi
# watchers.pyi
# __init__.pyi
# complete.pyi
# __init__.pyi
# argument.pyi
# context.pyi
# parser.pyi
# __init__.pyi
# METADATA.toml
# __init__.pyi
# METADATA.toml
# ast.pyi
# exceptions.pyi
# functions.pyi
# lexer.pyi
# parser.pyi
# visitor.pyi
# __init__.pyi
# METADATA.toml
# cli.pyi
# exceptions.pyi
# protocols.pyi
# validators.pyi
# _format.pyi
# _legacy_validators.pyi
# _reflect.pyi
# _types.pyi
# _utils.pyi
# _validators.pyi
# __init__.pyi
# METADATA.toml
# version.pyi
# __init__.pyi
# attrDef.pyi
# attribute.pyi
# cursor.pyi
# entry.pyi
# objectDef.pyi
# __init__.pyi
# connection.pyi
# exceptions.pyi
# pooling.pyi
# rdns.pyi
# results.pyi
# server.pyi
# timezone.pyi
# tls.pyi
# usage.pyi
# __init__.pyi
# operation.pyi
# __init__.pyi
# addMembersToGroups.pyi
# dirSync.pyi
# modifyPassword.pyi
# persistentSearch.pyi
# removeMembersFromGroups.pyi
# unlockAccount.pyi
# __init__.pyi
# addMembersToGroups.pyi
# checkGroupsMemberships.pyi
# endTransaction.pyi
# getBindDn.pyi
# listReplicas.pyi
# nmasGetUniversalPassword.pyi
# nmasSetUniversalPassword.pyi
# partition_entry_count.pyi
# removeMembersFromGroups.pyi
# replicaInfo.pyi
# startTransaction.pyi
# __init__.pyi
# modifyPassword.pyi
# PagedSearch.pyi
# PersistentSearch.pyi
# whoAmI.pyi
# __init__.pyi
# abandon.pyi
# add.pyi
# bind.pyi
# compare.pyi
# delete.pyi
# extended.pyi
# modify.pyi
# modifyDn.pyi
# search.pyi
# unbind.pyi
# __init__.pyi
# controls.pyi
# convert.pyi
# microsoft.pyi
# novell.pyi
# oid.pyi
# persistentSearch.pyi
# rfc2696.pyi
# rfc2849.pyi
# rfc3062.pyi
# rfc4511.pyi
# rfc4512.pyi
# rfc4527.pyi
# __init__.pyi
# formatters.pyi
# standard.pyi
# validators.pyi
# __init__.pyi
# digestMd5.pyi
# external.pyi
# kerberos.pyi
# plain.pyi
# sasl.pyi
# __init__.pyi
# ad2012R2.pyi
# ds389.pyi
# edir888.pyi
# edir914.pyi
# slapd24.pyi
# __init__.pyi
# asynchronous.pyi
# asyncStream.pyi
# base.pyi
# ldifProducer.pyi
# mockAsync.pyi
# mockBase.pyi
# mockSync.pyi
# restartable.pyi
# reusable.pyi
# safeRestartable.pyi
# safeSync.pyi
# sync.pyi
# __init__.pyi
# asn1.pyi
# ciDict.pyi
# config.pyi
# conv.pyi
# dn.pyi
# hashed.pyi
# log.pyi
# ntlm.pyi
# port_validators.pyi
# repr.pyi
# tls_backport.pyi
# uri.pyi
# __init__.pyi
# METADATA.toml
# blockparser.pyi
# blockprocessors.pyi
# core.pyi
# inlinepatterns.pyi
# pep562.pyi
# postprocessors.pyi
# preprocessors.pyi
# serializers.pyi
# treeprocessors.pyi
# util.pyi
# __init__.pyi
# __meta__.pyi
# abbr.pyi
# admonition.pyi
# attr_list.pyi
# codehilite.pyi
# def_list.pyi
# extra.pyi
# fenced_code.pyi
# footnotes.pyi
# legacy_attrs.pyi
# legacy_em.pyi
# md_in_html.pyi
# meta.pyi
# nl2br.pyi
# sane_lists.pyi
# smarty.pyi
# tables.pyi
# toc.pyi
# wikilinks.pyi
# __init__.pyi
# METADATA.toml
# mock.pyi
# __init__.pyi
# METADATA.toml
# mypy_extensions.pyi
# METADATA.toml
# connections.pyi
# converters.pyi
# cursors.pyi
# release.pyi
# times.pyi
# _exceptions.pyi
# _mysql.pyi
# __init__.pyi
# CLIENT.pyi
# CR.pyi
# ER.pyi
# FIELD_TYPE.pyi
# FLAG.pyi
# __init__.pyi
# METADATA.toml
# common.pyi
# __init__.pyi
# __init__.pyi
# errors.pyi
# parameters.pyi
# request_validator.pyi
# signature.pyi
# utils.pyi
# __init__.pyi
# access_token.pyi
# authorization.pyi
# base.pyi
# pre_configured.pyi
# request_token.pyi
# resource.pyi
# signature_only.pyi
# __init__.pyi
# __init__.pyi
# errors.pyi
# parameters.pyi
# request_validator.pyi
# tokens.pyi
# utils.pyi
# __init__.pyi
# backend_application.pyi
# base.pyi
# legacy_application.pyi
# mobile_application.pyi
# service_application.pyi
# web_application.pyi
# __init__.pyi
# authorization.pyi
# base.pyi
# introspect.pyi
# metadata.pyi
# pre_configured.pyi
# resource.pyi
# revocation.pyi
# token.pyi
# __init__.pyi
# authorization_code.pyi
# base.pyi
# client_credentials.pyi
# implicit.pyi
# refresh_token.pyi
# resource_owner_password_credentials.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# __init__.pyi
# .vsixmanifest
# CHANGELOG.md
# browser.extension.bundle.js
# browser.extension.bundle.js.LICENSE.txt
# browser.server.bundle.js
# browser.server.bundle.js.LICENSE.txt
# extension.bundle.js
# folderIndex.json
# stdlib.json
# etree.pyi
# objectify.pyi
# _multiarray_umath.pyi
# _simd.pyi
# _pocketfft_internal.pyi
# lapack_lite.pyi
# _umath_linalg.pyi
# bit_generator.pyi
# mtrand.pyi
# _bounded_integers.pyi
# _common.pyi
# _generator.pyi
# _mt19937.pyi
# _pcg64.pyi
# _philox.pyi
# _sfc64.pyi
# _sas.pyi
# algos.pyi
# groupby.pyi
# hashing.pyi
# hashtable.pyi
# index.pyi
# indexing.pyi
# internals.pyi
# interval.pyi
# join.pyi
# json.pyi
# lib.pyi
# missing.pyi
# ops.pyi
# ops_dispatch.pyi
# parsers.pyi
# properties.pyi
# reduction.pyi
# reshape.pyi
# sparse.pyi
# testing.pyi
# tslib.pyi
# writers.pyi
# base.pyi
# ccalendar.pyi
# conversion.pyi
# dtypes.pyi
# fields.pyi
# nattype.pyi
# np_datetime.pyi
# offsets.pyi
# parsing.pyi
# period.pyi
# strptime.pyi
# timedeltas.pyi
# timestamps.pyi
# timezones.pyi
# tzconversion.pyi
# vectorized.pyi
# aggregations.pyi
# indexers.pyi
# py.typed
# __init__.pyi
# commit.txt
# LICENSE.txt
# shortcuts.pyi
# __init__.pyi
# config.pyi
# registry.pyi
# __init__.pyi
# global_settings.pyi
# __init__.pyi
# __init__.pyi
# i18n.pyi
# static.pyi
# __init__.pyi
# __init__.pyi
# actions.pyi
# apps.pyi
# checks.pyi
# decorators.pyi
# exceptions.pyi
# filters.pyi
# forms.pyi
# helpers.pyi
# models.pyi
# options.pyi
# sites.pyi
# tests.pyi
# utils.pyi
# widgets.pyi
# __init__.pyi
# __init__.pyi
# admin_list.pyi
# admin_modify.pyi
# admin_urls.pyi
# base.pyi
# log.pyi
# __init__.pyi
# autocomplete.pyi
# decorators.pyi
# main.pyi
# __init__.pyi
# apps.pyi
# middleware.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# backends.pyi
# base_user.pyi
# checks.pyi
# context_processors.pyi
# decorators.pyi
# forms.pyi
# hashers.pyi
# middleware.pyi
# mixins.pyi
# models.pyi
# password_validation.pyi
# signals.pyi
# tokens.pyi
# urls.pyi
# validators.pyi
# views.pyi
# __init__.pyi
# modwsgi.pyi
# __init__.pyi
# __init__.pyi
# changepassword.pyi
# createsuperuser.pyi
# __init__.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# checks.pyi
# fields.pyi
# forms.pyi
# models.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# remove_stale_contenttypes.pyi
# __init__.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# forms.pyi
# middleware.pyi
# models.pyi
# sitemaps.pyi
# urls.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# flatpages.pyi
# __init__.pyi
# apps.pyi
# feeds.pyi
# geometry.pyi
# measure.pyi
# ptr.pyi
# shortcuts.pyi
# views.pyi
# __init__.pyi
# options.pyi
# widgets.pyi
# __init__.pyi
# __init__.pyi
# utils.pyi
# __init__.pyi
# adapter.pyi
# features.pyi
# models.pyi
# operations.pyi
# __init__.pyi
# base.pyi
# features.pyi
# introspection.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# adapter.pyi
# base.pyi
# features.pyi
# introspection.pyi
# models.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# adapter.pyi
# base.pyi
# const.pyi
# features.pyi
# introspection.pyi
# models.pyi
# operations.pyi
# pgraster.pyi
# schema.pyi
# __init__.pyi
# adapter.pyi
# base.pyi
# client.pyi
# features.pyi
# introspection.pyi
# models.pyi
# operations.pyi
# schema.pyi
# __init__.pyi
# aggregates.pyi
# fields.pyi
# functions.pyi
# lookups.pyi
# proxy.pyi
# __init__.pyi
# conversion.pyi
# __init__.pyi
# fields.pyi
# widgets.pyi
# __init__.pyi
# base.pyi
# datasource.pyi
# driver.pyi
# envelope.pyi
# error.pyi
# feature.pyi
# field.pyi
# geometries.pyi
# geomtype.pyi
# layer.pyi
# libgdal.pyi
# srs.pyi
# __init__.pyi
# ds.pyi
# errcheck.pyi
# generation.pyi
# geom.pyi
# raster.pyi
# srs.pyi
# __init__.pyi
# band.pyi
# base.pyi
# const.pyi
# source.pyi
# __init__.pyi
# base.pyi
# resources.pyi
# __init__.pyi
# base.pyi
# collections.pyi
# coordseq.pyi
# error.pyi
# factory.pyi
# geometry.pyi
# io.pyi
# libgeos.pyi
# linestring.pyi
# mutable_list.pyi
# point.pyi
# polygon.pyi
# prepared.pyi
# __init__.pyi
# coordseq.pyi
# errcheck.pyi
# geom.pyi
# io.pyi
# misc.pyi
# predicates.pyi
# prepared.pyi
# threadsafe.pyi
# topology.pyi
# __init__.pyi
# geojson.pyi
# __init__.pyi
# kml.pyi
# views.pyi
# __init__.pyi
# layermapping.pyi
# ogrinfo.pyi
# ogrinspect.pyi
# srs.pyi
# __init__.pyi
# apps.pyi
# __init__.pyi
# humanize.pyi
# __init__.pyi
# api.pyi
# apps.pyi
# constants.pyi
# context_processors.pyi
# middleware.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# base.pyi
# cookie.pyi
# fallback.pyi
# session.pyi
# __init__.pyi
# apps.pyi
# constraints.pyi
# functions.pyi
# indexes.pyi
# lookups.pyi
# operations.pyi
# search.pyi
# serializers.pyi
# signals.pyi
# utils.pyi
# validators.pyi
# __init__.pyi
# general.pyi
# mixins.pyi
# statistics.pyi
# __init__.pyi
# array.pyi
# citext.pyi
# hstore.pyi
# jsonb.pyi
# ranges.pyi
# utils.pyi
# __init__.pyi
# array.pyi
# hstore.pyi
# jsonb.py
# ranges.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# middleware.pyi
# models.pyi
# __init__.pyi
# __init__.pyi
# apps.pyi
# base_session.pyi
# exceptions.pyi
# middleware.pyi
# models.pyi
# serializers.pyi
# __init__.pyi
# base.pyi
# cache.pyi
# cached_db.pyi
# db.pyi
# file.pyi
# signed_cookies.pyi
# __init__.pyi
# __init__.pyi
# clearsessions.pyi
# __init__.pyi
# __init__.pyi
# apps.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# ping_google.pyi
# __init__.pyi
# admin.pyi
# apps.pyi
# management.pyi
# managers.pyi
# middleware.pyi
# models.pyi
# requests.pyi
# shortcuts.pyi
# __init__.pyi
# __init__.pyi
# apps.pyi
# checks.pyi
# finders.pyi
# handlers.pyi
# storage.pyi
# testing.pyi
# urls.pyi
# utils.pyi
# views.pyi
# __init__.pyi
# __init__.pyi
# collectstatic.pyi
# findstatic.pyi
# runserver.pyi
# __init__.pyi
# apps.pyi
# views.pyi
# __init__.pyi
# asgi.pyi
# exceptions.pyi
# paginator.pyi
# signals.pyi
# signing.pyi
# validators.pyi
# wsgi.pyi
# __init__.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# db.pyi
# dummy.pyi
# filebased.pyi
# locmem.pyi
# memcached.pyi
# __init__.pyi
# async_checks.pyi
# caches.pyi
# database.pyi
# messages.pyi
# model_checks.pyi
# registry.pyi
# templates.pyi
# translation.pyi
# urls.pyi
# __init__.pyi
# __init__.pyi
# base.pyi
# csrf.pyi
# sessions.pyi
# __init__.pyi
# base.pyi
# images.pyi
# locks.pyi
# move.pyi
# storage.pyi
# temp.pyi
# uploadedfile.pyi
# uploadhandler.pyi
# utils.pyi
# __init__.pyi
# asgi.pyi
# base.pyi
# exception.pyi
# wsgi.pyi
# __init__.pyi
# message.pyi
# utils.pyi
# __init__.pyi
# base.pyi
# console.pyi
# dummy.pyi
# filebased.pyi
# locmem.pyi
# smtp.pyi
# __init__.pyi
# base.pyi
# color.pyi
# sql.pyi
# templates.pyi
# utils.pyi
# __init__.pyi
# check.pyi
# compilemessages.pyi
# createcachetable.pyi
# dbshell.pyi
# diffsettings.pyi
# dumpdata.pyi
# flush.pyi
# inspectdb.pyi
# loaddata.pyi
# makemessages.pyi
# makemigrations.pyi
# migrate.pyi
# runserver.pyi
# sendtestemail.pyi
# shell.pyi
# showmigrations.pyi
# sqlflush.pyi
# ...
# fix_getcwdu.py
# fix_has_key.py
# fix_idioms.py
# fix_import.py
# fix_imports.py
# fix_imports2.py
# fix_input.py
# fix_intern.py
# fix_isinstance.py
# fix_itertools.py
# fix_itertools_imports.py
# fix_long.py
# fix_map.py
# fix_metaclass.py
# fix_methodattrs.py
# fix_ne.py
# fix_next.py
# fix_nonzero.py
# fix_numliterals.py
# fix_operator.py
# fix_paren.py
# fix_print.py
# fix_raise.py
# fix_raw_input.py
# fix_reduce.py
# fix_reload.py
# fix_renames.py
# fix_repr.py
# fix_set_literal.py
# fix_standarderror.py
# fix_sys_exc.py
# fix_throw.py
# fix_tuple_params.py
# fix_types.py
# fix_unicode.py
# fix_urllib.py
# fix_ws_comma.py
# fix_xrange.py
# fix_xreadlines.py
# fix_zip.py
# __init__.py
# fix_apply.cpython-38.pyc
# fix_asserts.cpython-38.pyc
# fix_basestring.cpython-38.pyc
# fix_buffer.cpython-38.pyc
# fix_dict.cpython-38.pyc
# fix_except.cpython-38.pyc
# fix_exec.cpython-38.pyc
# fix_execfile.cpython-38.pyc
# fix_exitfunc.cpython-38.pyc
# fix_filter.cpython-38.pyc
# fix_funcattrs.cpython-38.pyc
# fix_future.cpython-38.pyc
# fix_getcwdu.cpython-38.pyc
# fix_has_key.cpython-38.pyc
# fix_idioms.cpython-38.pyc
# fix_import.cpython-38.pyc
# fix_imports.cpython-38.pyc
# fix_imports2.cpython-38.pyc
# fix_input.cpython-38.pyc
# fix_intern.cpython-38.pyc
# fix_isinstance.cpython-38.pyc
# fix_itertools.cpython-38.pyc
# fix_itertools_imports.cpython-38.pyc
# fix_long.cpython-38.pyc
# fix_map.cpython-38.pyc
# fix_metaclass.cpython-38.pyc
# fix_methodattrs.cpython-38.pyc
# fix_ne.cpython-38.pyc
# fix_next.cpython-38.pyc
# fix_nonzero.cpython-38.pyc
# fix_numliterals.cpython-38.pyc
# fix_operator.cpython-38.pyc
# fix_paren.cpython-38.pyc
# fix_print.cpython-38.pyc
# fix_raise.cpython-38.pyc
# fix_raw_input.cpython-38.pyc
# fix_reduce.cpython-38.pyc
# fix_reload.cpython-38.pyc
# fix_renames.cpython-38.pyc
# fix_repr.cpython-38.pyc
# fix_set_literal.cpython-38.pyc
# fix_standarderror.cpython-38.pyc
# fix_sys_exc.cpython-38.pyc
# fix_throw.cpython-38.pyc
# fix_tuple_params.cpython-38.pyc
# fix_types.cpython-38.pyc
# fix_unicode.cpython-38.pyc
# fix_urllib.cpython-38.pyc
# fix_ws_comma.cpython-38.pyc
# fix_xrange.cpython-38.pyc
# fix_xreadlines.cpython-38.pyc
# fix_zip.cpython-38.pyc
# __init__.cpython-38.pyc
# conv.py
# driver.py
# grammar.py
# literals.py
# parse.py
# pgen.py
# token.py
# tokenize.py
# __init__.py
# conv.cpython-38.pyc
# driver.cpython-38.pyc
# grammar.cpython-38.pyc
# literals.cpython-38.pyc
# parse.cpython-38.pyc
# pgen.cpython-38.pyc
# token.cpython-38.pyc
# tokenize.cpython-38.pyc
# __init__.cpython-38.pyc
# btm_matcher.cpython-38.pyc
# btm_utils.cpython-38.pyc
# fixer_base.cpython-38.pyc
# fixer_util.cpython-38.pyc
# main.cpython-38.pyc
# patcomp.cpython-38.pyc
# pygram.cpython-38.pyc
# pytree.cpython-38.pyc
# refactor.cpython-38.pyc
# __init__.cpython-38.pyc
# __main__.cpython-38.pyc
# config.py
# handlers.py
# __init__.py
# config.cpython-38.pyc
# handlers.cpython-38.pyc
# __init__.cpython-38.pyc
# schema.py
# sequence.py
# text.py
# __init__.py
# schema.cpython-38.pyc
# sequence.cpython-38.pyc
# text.cpython-38.pyc
# __init__.cpython-38.pyc
# connection.py
# context.py
# forkserver.py
# heap.py
# managers.py
# pool.py
# popen_fork.py
# popen_forkserver.py
# popen_spawn_posix.py
# popen_spawn_win32.py
# process.py
# queues.py
# reduction.py
# resource_sharer.py
# resource_tracker.py
# sharedctypes.py
# shared_memory.py
# spawn.py
# synchronize.py
# util.py
# __init__.py
# connection.py
# __init__.py
# connection.cpython-38.pyc
# __init__.cpython-38.pyc
# connection.cpython-38.pyc
# context.cpython-38.pyc
# forkserver.cpython-38.pyc
# heap.cpython-38.pyc
# managers.cpython-38.pyc
# pool.cpython-38.pyc
# popen_fork.cpython-38.pyc
# popen_forkserver.cpython-38.pyc
# popen_spawn_posix.cpython-38.pyc
# popen_spawn_win32.cpython-38.pyc
# process.cpython-38.pyc
# queues.cpython-38.pyc
# reduction.cpython-38.pyc
# resource_sharer.cpython-38.pyc
# resource_tracker.cpython-38.pyc
# sharedctypes.cpython-38.pyc
# shared_memory.cpython-38.pyc
# spawn.cpython-38.pyc
# synchronize.cpython-38.pyc
# util.cpython-38.pyc
# __init__.cpython-38.pyc
# topics.py
# _pydoc.css
# __init__.py
# topics.cpython-38.pyc
# __init__.cpython-38.pyc
# distutils-precedence.pth
# README.txt
# wincertstore-0.2-py3.8.egg-info
# wincertstore.py
# cacert.pem
# core.py
# py.typed
# __init__.py
# __main__.py
# core.cpython-38.pyc
# __init__.cpython-38.pyc
# __main__.cpython-38.pyc
# direct_url.json
# INSTALLER
# LICENSE
# METADATA
# RECORD
# REQUESTED
# top_level.txt
# WHEEL
# py.typed
# __init__.py
# __main__.py
# build_env.py
# cache.py
# configuration.py
# exceptions.py
# main.py
# pyproject.py
# self_outdated_check.py
# wheel_builder.py
# __init__.py
# autocompletion.py
# base_command.py
# cmdoptions.py
# command_context.py
# main.py
# main_parser.py
# parser.py
# progress_bars.py
# req_command.py
# spinners.py
# status_codes.py
# __init__.py
# autocompletion.cpython-38.pyc
# base_command.cpython-38.pyc
# cmdoptions.cpython-38.pyc
# command_context.cpython-38.pyc
# main.cpython-38.pyc
# main_parser.cpython-38.pyc
# parser.cpython-38.pyc
# progress_bars.cpython-38.pyc
# req_command.cpython-38.pyc
# spinners.cpython-38.pyc
# status_codes.cpython-38.pyc
# __init__.cpython-38.pyc
# cache.py
# check.py
# completion.py
# configuration.py
# debug.py
# download.py
# freeze.py
# hash.py
# help.py
# index.py
# install.py
# list.py
# search.py
# show.py
# uninstall.py
# wheel.py
# __init__.py
# cache.cpython-38.pyc
# check.cpython-38.pyc
# completion.cpython-38.pyc
# configuration.cpython-38.pyc
# debug.cpython-38.pyc
# download.cpython-38.pyc
# freeze.cpython-38.pyc
# hash.cpython-38.pyc
# help.cpython-38.pyc
# index.cpython-38.pyc
# install.cpython-38.pyc
# list.cpython-38.pyc
# search.cpython-38.pyc
# show.cpython-38.pyc
# uninstall.cpython-38.pyc
# wheel.cpython-38.pyc
# __init__.cpython-38.pyc
# base.py
# installed.py
# sdist.py
# wheel.py
# __init__.py
# base.cpython-38.pyc
# installed.cpython-38.pyc
# sdist.cpython-38.pyc
# wheel.cpython-38.pyc
# __init__.cpython-38.pyc
# collector.py
# package_finder.py
# sources.py
# __init__.py
# collector.cpython-38.pyc
# package_finder.cpython-38.pyc
# sources.cpython-38.pyc
# __init__.cpython-38.pyc
# base.py
# _distutils.py
# _sysconfig.py
# __init__.py
# base.cpython-38.pyc
# _distutils.cpython-38.pyc
# _sysconfig.cpython-38.pyc
# __init__.cpython-38.pyc
# base.py
# pkg_resources.py
# __init__.py
# _compat.py
# _dists.py
# _envs.py
# __init__.py
# _compat.cpython-38.pyc
# _dists.cpython-38.pyc
# _envs.cpython-38.pyc
# __init__.cpython-38.pyc
# base.cpython-38.pyc
# pkg_resources.cpython-38.pyc
# __init__.cpython-38.pyc
# candidate.py
# direct_url.py
# format_control.py
# index.py
# link.py
# scheme.py
# search_scope.py
# selection_prefs.py
# target_python.py
# wheel.py
# __init__.py
# candidate.cpython-38.pyc
# direct_url.cpython-38.pyc
# format_control.cpython-38.pyc
# index.cpython-38.pyc
# link.cpython-38.pyc
# scheme.cpython-38.pyc
# search_scope.cpython-38.pyc
# selection_prefs.cpython-38.pyc
# target_python.cpython-38.pyc
# wheel.cpython-38.pyc
# __init__.cpython-38.pyc
# auth.py
# cache.py
# download.py
# lazy_wheel.py
# session.py
# utils.py
# xmlrpc.py
# __init__.py
# auth.cpython-38.pyc
# cache.cpython-38.pyc
# download.cpython-38.pyc
# lazy_wheel.cpython-38.pyc
# session.cpython-38.pyc
# utils.cpython-38.pyc
# xmlrpc.cpython-38.pyc
# __init__.cpython-38.pyc
# check.py
# freeze.py
# prepare.py
# __init__.py
# build_tracker.py
# metadata.py
# metadata_editable.py
# metadata_legacy.py
# wheel.py
# wheel_editable.py
# wheel_legacy.py
# __init__.py
# build_tracker.cpython-38.pyc
# metadata.cpython-38.pyc
# metadata_editable.cpython-38.pyc
# metadata_legacy.cpython-38.pyc
# wheel.cpython-38.pyc
# wheel_editable.cpython-38.pyc
# wheel_legacy.cpython-38.pyc
# __init__.cpython-38.pyc
# editable_legacy.py
# legacy.py
# wheel.py
# __init__.py
# editable_legacy.cpython-38.pyc
# legacy.cpython-38.pyc
# wheel.cpython-38.pyc
# __init__.cpython-38.pyc
# check.cpython-38.pyc
# freeze.cpython-38.pyc
# prepare.cpython-38.pyc
# __init__.cpython-38.pyc
# constructors.py
# req_file.py
# req_install.py
# req_set.py
# req_uninstall.py
# __init__.py
# constructors.cpython-38.pyc
# req_file.cpython-38.pyc
# req_install.cpython-38.pyc
# req_set.cpython-38.pyc
# req_uninstall.cpython-38.pyc
# __init__.cpython-38.pyc
# base.py
# __init__.py
# resolver.py
# __init__.py
# resolver.cpython-38.pyc
# __init__.cpython-38.pyc
# base.py
# candidates.py
# factory.py
# found_candidates.py
# provider.py
# reporter.py
# requirements.py
# resolver.py
# __init__.py
# base.cpython-38.pyc
# candidates.cpython-38.pyc
# factory.cpython-38.pyc
# found_candidates.cpython-38.pyc
# provider.cpython-38.pyc
# reporter.cpython-38.pyc
# requirements.cpython-38.pyc
# resolver.cpython-38.pyc
# __init__.cpython-38.pyc
# base.cpython-38.pyc
# __init__.cpython-38.pyc
# appdirs.py
# compat.py
# compatibility_tags.py
# datetime.py
# deprecation.py
# direct_url_helpers.py
# distutils_args.py
# egg_link.py
# encoding.py
# entrypoints.py
# filesystem.py
# filetypes.py
# glibc.py
# hashes.py
# inject_securetransport.py
# logging.py
# misc.py
# models.py
# packaging.py
# setuptools_build.py
# subprocess.py
# temp_dir.py
# unpacking.py
# urls.py
# virtualenv.py
# wheel.py
# _log.py
# __init__.py
# appdirs.cpython-38.pyc
# compat.cpython-38.pyc
# compatibility_tags.cpython-38.pyc
# datetime.cpython-38.pyc
# deprecation.cpython-38.pyc
# direct_url_helpers.cpython-38.pyc
# distutils_args.cpython-38.pyc
# egg_link.cpython-38.pyc
# encoding.cpython-38.pyc
# entrypoints.cpython-38.pyc
# filesystem.cpython-38.pyc
# filetypes.cpython-38.pyc
# glibc.cpython-38.pyc
# hashes.cpython-38.pyc
# inject_securetransport.cpython-38.pyc
# logging.cpython-38.pyc
# misc.cpython-38.pyc
# models.cpython-38.pyc
# packaging.cpython-38.pyc
# setuptools_build.cpython-38.pyc
# subprocess.cpython-38.pyc
# temp_dir.cpython-38.pyc
# unpacking.cpython-38.pyc
# urls.cpython-38.pyc
# virtualenv.cpython-38.pyc
# wheel.cpython-38.pyc
# _log.cpython-38.pyc
# __init__.cpython-38.pyc
# bazaar.py
# git.py
# mercurial.py
# subversion.py
# versioncontrol.py
# __init__.py
# bazaar.cpython-38.pyc
# git.cpython-38.pyc
# mercurial.cpython-38.pyc
# subversion.cpython-38.pyc
# versioncontrol.cpython-38.pyc
# __init__.cpython-38.pyc
# build_env.cpython-38.pyc
# cache.cpython-38.pyc
# configuration.cpython-38.pyc
# exceptions.cpython-38.pyc
# main.cpython-38.pyc
# pyproject.cpython-38.pyc
# self_outdated_check.cpython-38.pyc
# wheel_builder.cpython-38.pyc
# __init__.cpython-38.pyc
# six.py
# typing_extensions.py
# vendor.txt
# __init__.py
# adapter.py
# cache.py
# compat.py
# controller.py
# filewrapper.py
# heuristics.py
# serialize.py
# wrapper.py
# _cmd.py
# __init__.py
# file_cache.py
# redis_cache.py
# __init__.py
# file_cache.cpython-38.pyc
# redis_cache.cpython-38.pyc
# __init__.cpython-38.pyc
# adapter.cpython-38.pyc
# cache.cpython-38.pyc
# compat.cpython-38.pyc
# controller.cpython-38.pyc
# filewrapper.cpython-38.pyc
# heuristics.cpython-38.pyc
# serialize.cpython-38.pyc
# wrapper.cpython-38.pyc
# _cmd.cpython-38.pyc
# __init__.cpython-38.pyc
# cacert.pem
# core.py
# __init__.py
# __main__.py
# core.cpython-38.pyc
# __init__.cpython-38.pyc
# __main__.cpython-38.pyc
# big5freq.py
# big5prober.py
# chardistribution.py
# charsetgroupprober.py
# charsetprober.py
# codingstatemachine.py
# compat.py
# cp949prober.py
# enums.py
# escprober.py
# escsm.py
# eucjpprober.py
# euckrfreq.py
# euckrprober.py
# euctwfreq.py
# euctwprober.py
# gb2312freq.py
# gb2312prober.py
# hebrewprober.py
# jisfreq.py
# jpcntx.py
# langbulgarianmodel.py
# langgreekmodel.py
# langhebrewmodel.py
# langhungarianmodel.py
# langrussianmodel.py
# langthaimodel.py
# langturkishmodel.py
# latin1prober.py
# mbcharsetprober.py
# mbcsgroupprober.py
# mbcssm.py
# sbcharsetprober.py
# sbcsgroupprober.py
# sjisprober.py
# universaldetector.py
# utf8prober.py
# version.py
# __init__.py
# chardetect.py
# __init__.py
# chardetect.cpython-38.pyc
# __init__.cpython-38.pyc
# languages.py
# __init__.py
# languages.cpython-38.pyc
# __init__.cpython-38.pyc
# big5freq.cpython-38.pyc
# big5prober.cpython-38.pyc
# chardistribution.cpython-38.pyc
# charsetgroupprober.cpython-38.pyc
# charsetprober.cpython-38.pyc
# codingstatemachine.cpython-38.pyc
# compat.cpython-38.pyc
# cp949prober.cpython-38.pyc
# enums.cpython-38.pyc
# escprober.cpython-38.pyc
# escsm.cpython-38.pyc
# eucjpprober.cpython-38.pyc
# euckrfreq.cpython-38.pyc
# euckrprober.cpython-38.pyc
# euctwfreq.cpython-38.pyc
# euctwprober.cpython-38.pyc
# gb2312freq.cpython-38.pyc
# gb2312prober.cpython-38.pyc
# hebrewprober.cpython-38.pyc
# jisfreq.cpython-38.pyc
# jpcntx.cpython-38.pyc
# langbulgarianmodel.cpython-38.pyc
# langgreekmodel.cpython-38.pyc
# langhebrewmodel.cpython-38.pyc
# langhungarianmodel.cpython-38.pyc
# langrussianmodel.cpython-38.pyc
# langthaimodel.cpython-38.pyc
# langturkishmodel.cpython-38.pyc
# latin1prober.cpython-38.pyc
# mbcharsetprober.cpython-38.pyc
# mbcsgroupprober.cpython-38.pyc
# mbcssm.cpython-38.pyc
# sbcharsetprober.cpython-38.pyc
# sbcsgroupprober.cpython-38.pyc
# sjisprober.cpython-38.pyc
# universaldetector.cpython-38.pyc
# utf8prober.cpython-38.pyc
# version.cpython-38.pyc
# __init__.cpython-38.pyc
# ansi.py
# ansitowin32.py
# initialise.py
# win32.py
# winterm.py
# __init__.py
# ansi.cpython-38.pyc
# ansitowin32.cpython-38.pyc
# initialise.cpython-38.pyc
# win32.cpython-38.pyc
# winterm.cpython-38.pyc
# __init__.cpython-38.pyc
# compat.py
# database.py
# index.py
# locators.py
# manifest.py
# markers.py
# metadata.py
# resources.py
# scripts.py
# t32.exe
# t64-arm.exe
# t64.exe
# util.py
# version.py
# w32.exe
# w64-arm.exe
# w64.exe
# wheel.py
# __init__.py
# misc.py
# shutil.py
# sysconfig.cfg
# sysconfig.py
# tarfile.py
# __init__.py
# misc.cpython-38.pyc
# shutil.cpython-38.pyc
# sysconfig.cpython-38.pyc
# tarfile.cpython-38.pyc
# __init__.cpython-38.pyc
# compat.cpython-38.pyc
# database.cpython-38.pyc
# index.cpython-38.pyc
# locators.cpython-38.pyc
# manifest.cpython-38.pyc
# markers.cpython-38.pyc
# metadata.cpython-38.pyc
# resources.cpython-38.pyc
# scripts.cpython-38.pyc
# util.cpython-38.pyc
# version.cpython-38.pyc
# wheel.cpython-38.pyc
# __init__.cpython-38.pyc
# distro.py
# __init__.py
# __main__.py
# distro.cpython-38.pyc
# __init__.cpython-38.pyc
# __main__.cpython-38.pyc
# constants.py
# html5parser.py
# serializer.py
# _ihatexml.py
# _inputstream.py
# _tokenizer.py
# _utils.py
# __init__.py
# alphabeticalattributes.py
# base.py
# inject_meta_charset.py
# lint.py
# optionaltags.py
# sanitizer.py
# whitespace.py
# __init__.py
# alphabeticalattributes.cpython-38.pyc
# base.cpython-38.pyc
# inject_meta_charset.cpython-38.pyc
# lint.cpython-38.pyc
# optionaltags.cpython-38.pyc
# sanitizer.cpython-38.pyc
# whitespace.cpython-38.pyc
# __init__.cpython-38.pyc
# genshi.py
# sax.py
# __init__.py
# genshi.cpython-38.pyc
# sax.cpython-38.pyc
# __init__.cpython-38.pyc
# base.py
# dom.py
# etree.py
# etree_lxml.py
# __init__.py
# base.cpython-38.pyc
# dom.cpython-38.pyc
# etree.cpython-38.pyc
# etree_lxml.cpython-38.pyc
# __init__.cpython-38.pyc
# base.py
# dom.py
# etree.py
# etree_lxml.py
# genshi.py
# __init__.py
# base.cpython-38.pyc
# dom.cpython-38.pyc
# etree.cpython-38.pyc
# etree_lxml.cpython-38.pyc
# genshi.cpython-38.pyc
# __init__.cpython-38.pyc
# py.py
# _base.py
# __init__.py
# py.cpython-38.pyc
# _base.cpython-38.pyc
# __init__.cpython-38.pyc
# constants.cpython-38.pyc
# html5parser.cpython-38.pyc
# serializer.cpython-38.pyc
# _ihatexml.cpython-38.pyc
# _inputstream.cpython-38.pyc
# _tokenizer.cpython-38.pyc
# _utils.cpython-38.pyc
# __init__.cpython-38.pyc
# codec.py
# compat.py
# core.py
# idnadata.py
# intranges.py
# package_data.py
# uts46data.py
# __init__.py
# codec.cpython-38.pyc
# compat.cpython-38.pyc
# core.cpython-38.pyc
# idnadata.cpython-38.pyc
# intranges.cpython-38.pyc
# package_data.cpython-38.pyc
# uts46data.cpython-38.pyc
# __init__.cpython-38.pyc
# exceptions.py
# ext.py
# fallback.py
# _version.py
# __init__.py
# exceptions.cpython-38.pyc
# ext.cpython-38.pyc
# fallback.cpython-38.pyc
# _version.cpython-38.pyc
# __init__.cpython-38.pyc
# markers.py
# requirements.py
# specifiers.py
# tags.py
# utils.py
# version.py
# _manylinux.py
# _musllinux.py
# _structures.py
# __about__.py
# __init__.py
# markers.cpython-38.pyc
# requirements.cpython-38.pyc
# specifiers.cpython-38.pyc
# tags.cpython-38.pyc
# utils.cpython-38.pyc
# version.cpython-38.pyc
# _manylinux.cpython-38.pyc
# _musllinux.cpython-38.pyc
# _structures.cpython-38.pyc
# __about__.cpython-38.pyc
# __init__.cpython-38.pyc
# build.py
# check.py
# colorlog.py
# compat.py
# dirtools.py
# envbuild.py
# meta.py
# wrappers.py
# __init__.py
# _in_process.py
# __init__.py
# _in_process.cpython-38.pyc
# __init__.cpython-38.pyc
# build.cpython-38.pyc
# check.cpython-38.pyc
# colorlog.cpython-38.pyc
# compat.cpython-38.pyc
# dirtools.cpython-38.pyc
# envbuild.cpython-38.pyc
# meta.cpython-38.pyc
# wrappers.cpython-38.pyc
# __init__.cpython-38.pyc
# py31compat.py
# __init__.py
# py31compat.cpython-38.pyc
# __init__.cpython-38.pyc
# android.py
# api.py
# macos.py
# unix.py
# version.py
# windows.py
# __init__.py
# __main__.py
# android.cpython-38.pyc
# api.cpython-38.pyc
# macos.cpython-38.pyc
# unix.cpython-38.pyc
# version.cpython-38.pyc
# windows.cpython-38.pyc
# __init__.cpython-38.pyc
# __main__.cpython-38.pyc
# cmdline.py
# console.py
# filter.py
# formatter.py
# lexer.py
# modeline.py
# plugin.py
# regexopt.py
# scanner.py
# sphinxext.py
# style.py
# token.py
# unistring.py
# util.py
# __init__.py
# __main__.py

# %% [markdown]
# **5. Create a list of all of the files in your parent directory (minimum five files should be available).**

# %%
import os 
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.gitconfig',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.vscode',
#  '3D Objects',
#  'anaconda3',
#  'ansel',
#  'AppData',
#  'Application Data',
#  'application_log.txt',
#  'BlueStacks X',
#  'BlueStacks_nxt',
#  'books.csv',
#  'books.db',
#  'Class-10 _4th JUNE.ipynb',
#  'Class-11 _ (5th JUNE).ipynb',
#  'Class-13 _(12th JUNE).ipynb',
#  'Class-14 _(18th JUNE).ipynb',
#  'Class-17 30th JUNE.ipynb',
#  'Class-6__(21st  MAY).ipynb',
#  'CLASS-7 NOTES _(22nd May).ipynb',
#  'CLASS-8__(28th MAY).ipynb',
#  'Class-9 __(29th MAY).ipynb',
#  'class_4 (15th NOVEMBER).ipynb',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Div.txt',
#  'Divesh',
#  'divesh1.txt',
#  'Documents',
#  'Downloads',
#  'edyst_project-1.ipynb',
#  'edyst_project-2.ipynb',
#  'Favorites',
#  'file.avi',
#  'file.BCS',
#  'file.db',
#  'file.dbb',
#  'file.dmp',
#  'file.DSP',
#  'file.err',
#  'file.esav',
#  'file.full',
#  'file.log',
#  'file.mlv',
#  'file.mntr',
#  'file.mode',
#  'file.rst',
#  'file.rsx',
#  'file.rth',
#  'file.stat',
#  'FSDS-EDA.ipynb',
#  'INEURON',
#  'Linear_Regression-Model.ipynb',
#  'Links',
#  'list.txt',
#  'Local Settings',
#  'Logistic-Regression_MODEL.ipynb',
#  'Multilayer Perceptron_ML-MODEL.ipynb',
#  'multilayer-perceptron_Model.ipynb',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{1c2b59c5-c5f5-11eb-bacb-000d3a96488e}.TxR.blf',
#  'NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TM.blf',
#  'NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PRACTICE OF CLASSS_3.ipynb',
#  'PrintHood',
#  'PycharmProjects',
#  'Python Basic Assignment - 1.ipynb',
#  'Python Basic Assignment - 10.ipynb',
#  'Python Basic Assignment - 11.ipynb',
#  'Python Basic Assignment - 12.ipynb',
#  'Python Basic Assignment - 13.ipynb',
#  'Python Basic Assignment - 14.ipynb',
#  'Python Basic Assignment - 15.ipynb',
#  'Python Basic Assignment - 16.ipynb',
#  'Python Basic Assignment - 17.ipynb',
#  'Python Basic Assignment - 18.ipynb',
#  'Python Basic Assignment - 19.ipynb',
#  'Python Basic Assignment - 2.ipynb',
#  'Python Basic Assignment - 20.ipynb',
#  'Python Basic Assignment - 3.ipynb',
#  'Python Basic Assignment - 4.ipynb',
#  'Python Basic Assignment - 5.ipynb',
#  'Python Basic Assignment - 6.ipynb',
#  'Python Basic Assignment - 7.ipynb',
#  'Python Basic Assignment - 8.ipynb',
#  'Python Basic Assignment - 9.ipynb',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'TASK-1 __(Class -- 4).ipynb',
#  'TASK-2_CLASS-6.ipynb',
#  'TASK-3__Class-8.ipynb',
#  'TASK-4 _Class-9.ipynb',
#  'TASK-5 _ Class-11.ipynb',
#  'Templates',
#  'test.ipynb',
#  'test.txt',
#  'test5.txt',
#  'test6.txt',
#  'test7.txt',
#  'testd.txt',
#  'today.txt',
#  'university_records.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled18.ipynb',
#  'Untitled19.ipynb',
#  'Untitled2.ipynb',
#  'Untitled20.ipynb',
#  'Untitled21.ipynb',
#  'Untitled22.ipynb',
#  'Untitled23.ipynb',
#  'Untitled24.ipynb',
#  'Untitled25.ipynb',
#  'Untitled26.ipynb',
#  'Untitled27.ipynb',
#  'Untitled28.ipynb',
#  'Untitled29.ipynb',
#  'Untitled3.ipynb',
#  'Untitled30.ipynb',
#  'Untitled31.ipynb',
#  'Untitled32.ipynb',
#  'Untitled33.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'Videos',
#  'WORK-3.ipynb']

# %% [markdown]
# **6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.**

# %%
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()
# Out:
# Proc_one_Starttime -> 2022-05-08 05:34:54.746835
# Proc_two_Starttime -> 2022-05-08 05:34:54.756046
# Proc_two_Starttime -> 2022-05-08 05:34:54.771798
# Proc_two_Endtime -> 2022-05-08 05:34:55.777636
# Proc_two_Endtime -> 2022-05-08 05:34:56.764917
# Proc_one_Endtime -> 2022-05-08 05:34:57.764113

# %% [markdown]
# **7. Create a date object of your day of birth.**

# %%
from datetime import datetime
my_dob = datetime.strptime('12/01/1994','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 1994-01-12 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# **8. What day of the week was your day of birth?**

# %%
from datetime import datetime
my_dob = datetime(1994,1,12)
my_dob.strftime("%A")
# Out:
# 'Wednesday'

# %% [markdown]
# **9. When will you be (or when were you) 10,000 days old?**

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("12/01/1994",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1966, 8, 27, 0, 0)
